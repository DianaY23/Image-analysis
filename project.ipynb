# %%
Подключение google disk для использования dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Установка библиотеки

# %%
# !pip install petroscope
# Out:
# Requirement already satisfied: petroscope in /usr/local/lib/python3.11/dist-packages (0.0.11)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from petroscope) (6.0.2)
# Requirement already satisfied: numpy<2.0.0,>=1.16 in /usr/local/lib/python3.11/dist-packages (from petroscope) (1.26.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from petroscope) (11.1.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from petroscope) (3.10.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from petroscope) (4.67.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from petroscope) (1.14.1)
# Requirement already satisfied: loguru in /usr/local/lib/python3.11/dist-packages (from petroscope) (0.7.3)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.11/dist-packages (from petroscope) (3.15.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from petroscope) (2.32.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->petroscope) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->petroscope) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->petroscope) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->petroscope) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->petroscope) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->petroscope) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->petroscope) (2.8.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prettytable->petroscope) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->petroscope) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->petroscope) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->petroscope) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->petroscope) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->petroscope) (1.17.0)

# %% [markdown]
# Импорт неободимых библиотек

# %%
from pathlib import Path
from petroscope.segmentation.classes import ClassSet, LumenStoneClasses
from petroscope.segmentation.utils import load_image, load_mask
from petroscope.segmentation import GeoSegmModel
import numpy as np
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from skimage.color import rgb2lab
import os

# %% [markdown]
# Путь к dataset

# %%
ds_path = Path('/content/drive/MyDrive/PhotoSets/')

# %% [markdown]
# Инциализация набора классов для сегментации

# %%
classset = LumenStoneClasses.S1v1()

for cl in classset.classes:
    print(cl)
# Out:
# [0, bg (background), color: #000000]
# [1, ccp/kub (chalcopyrite/cubanite), color: #ffa500]
# [2, gl (galena), color: #9acd32]
# [4, brt (bornite), color: #00bfff]
# [6, py/mrc (pyrite/marcasite), color: #2f4f4f]
# [8, sph (sphalerite), color: #ee82ee]
# [11, tnt/ttr (tenantite/tetrahedrite), color: #483d8b]

# %% [markdown]
# Формирование путей к изображениям и маскам

# %%
train_img_mask_p = [
    (img_p, ds_path / "masks" / "train" / f"{img_p.stem}.png")
    for img_p in sorted((ds_path / "imgs" / "train").iterdir())
]

test_img_mask_p = [
    (img_p, ds_path / "masks" / "test" / f"{img_p.stem}.png")
    for img_p in sorted((ds_path / "imgs" / "test").iterdir())
]

# %% [markdown]
# Загрузка и конвертация обучающих изображений в пространство LAB

# %%
for img_p, _ in train_img_mask_p:
    img = load_image(img_p, normalize=True)
    img_lab = rgb2lab(img)
    print(f"Image {img_p.name}: {img_lab.shape}, {img_lab.dtype}")
# Out:
# Image train_01.jpg: (2547, 3396, 3), float32
# Image train_02.jpg: (2547, 3396, 3), float32
# Image train_03.jpg: (2547, 3396, 3), float32
# Image train_04.jpg: (2547, 3396, 3), float32
# Image train_06.jpg: (2547, 3396, 3), float32
# Image train_07.jpg: (2547, 3396, 3), float32
# Image train_08.jpg: (2547, 3396, 3), float32
# Image train_09.jpg: (2547, 3396, 3), float32
# Image train_10.jpg: (2547, 3396, 3), float32
# Image train_11.jpg: (2547, 3396, 3), float32
# Image train_12.jpg: (2547, 3396, 3), float32
# Image train_13.jpg: (2547, 3396, 3), float32
# Image train_14.jpg: (2547, 3396, 3), float32
# Image train_15.jpg: (2547, 3396, 3), float32
# Image train_16.jpg: (2547, 3396, 3), float32
# Image train_17.jpg: (2547, 3396, 3), float32
# Image train_18.jpg: (2547, 3396, 3), float32
# Image train_19.jpg: (2547, 3396, 3), float32
# Image train_20.jpg: (2547, 3396, 3), float32
# Image train_21.jpg: (2547, 3396, 3), float32
# Image train_22.jpg: (2547, 3396, 3), float32
# Image train_23.jpg: (2547, 3396, 3), float32
# Image train_24.jpg: (2547, 3396, 3), float32
# Image train_25.jpg: (2547, 3396, 3), float32
# Image train_26.jpg: (2547, 3396, 3), float32
# Image train_27.jpg: (2547, 3396, 3), float32
# Image train_28.jpg: (2547, 3396, 3), float32
# Image train_29.jpg: (2547, 3396, 3), float32
# Image train_30.jpg: (2547, 3396, 3), float32
# Image train_31.jpg: (2547, 3396, 3), float32
# Image train_32.jpg: (2547, 3396, 3), float32
# Image train_33.jpg: (2547, 3396, 3), float32
# Image train_34.jpg: (2547, 3396, 3), float32
# Image train_35.jpg: (2547, 3396, 3), float32
# Image train_36.jpg: (2547, 3396, 3), float32
# Image train_37.jpg: (2547, 3396, 3), float32
# Image train_38.jpg: (2547, 3396, 3), float32
# Image train_39.jpg: (2547, 3396, 3), float32
# Image train_40.jpg: (2547, 3396, 3), float32
# Image train_41.jpg: (2547, 3396, 3), float32
# Image train_42.jpg: (2547, 3396, 3), float32
# Image train_43.jpg: (2547, 3396, 3), float32
# Image train_44.jpg: (2547, 3396, 3), float32
# Image train_45.jpg: (2547, 3396, 3), float32
# Image train_46.jpg: (2547, 3396, 3), float32
# Image train_47.jpg: (2547, 3396, 3), float32
# Image train_48.jpg: (2547, 3396, 3), float32
# Image train_49.jpg: (2547, 3396, 3), float32
# Image train_50.jpg: (2547, 3396, 3), float32
# Image train_51.jpg: (2547, 3396, 3), float32
# Image train_52.jpg: (2547, 3396, 3), float32
# Image train_53.jpg: (2547, 3396, 3), float32
# Image train_54.jpg: (2547, 3396, 3), float32
# Image train_55.jpg: (2547, 3396, 3), float32
# Image train_56.jpg: (2547, 3396, 3), float32
# Image train_57.jpg: (2547, 3396, 3), float32
# Image train_58.jpg: (2547, 3396, 3), float32
# Image train_59.jpg: (2547, 3396, 3), float32

# %% [markdown]
# Загрузка масок без one-hot кодирования

# %%
for _, mask_p in train_img_mask_p:
    mask = load_mask(mask_p, classes=classset, one_hot=False)
    print(f"Mask {mask_p.name}: {mask.shape}, {mask.dtype}")
# Out:
# Mask train_01.png: (2547, 3396), uint8
# Mask train_02.png: (2547, 3396), uint8
# Mask train_03.png: (2547, 3396), uint8
# Mask train_04.png: (2547, 3396), uint8
# Mask train_06.png: (2547, 3396), uint8
# Mask train_07.png: (2547, 3396), uint8
# Mask train_08.png: (2547, 3396), uint8
# Mask train_09.png: (2547, 3396), uint8
# Mask train_10.png: (2547, 3396), uint8
# Mask train_11.png: (2547, 3396), uint8
# Mask train_12.png: (2547, 3396), uint8
# Mask train_13.png: (2547, 3396), uint8
# Mask train_14.png: (2547, 3396), uint8
# Mask train_15.png: (2547, 3396), uint8
# Mask train_16.png: (2547, 3396), uint8
# Mask train_17.png: (2547, 3396), uint8
# Mask train_18.png: (2547, 3396), uint8
# Mask train_19.png: (2547, 3396), uint8
# Mask train_20.png: (2547, 3396), uint8
# Mask train_21.png: (2547, 3396), uint8
# Mask train_22.png: (2547, 3396), uint8
# Mask train_23.png: (2547, 3396), uint8
# Mask train_24.png: (2547, 3396), uint8
# Mask train_25.png: (2547, 3396), uint8
# Mask train_26.png: (2547, 3396), uint8
# Mask train_27.png: (2547, 3396), uint8
# Mask train_28.png: (2547, 3396), uint8
# Mask train_29.png: (2547, 3396), uint8
# Mask train_30.png: (2547, 3396), uint8
# Mask train_31.png: (2547, 3396), uint8
# Mask train_32.png: (2547, 3396), uint8
# Mask train_33.png: (2547, 3396), uint8
# Mask train_34.png: (2547, 3396), uint8
# Mask train_35.png: (2547, 3396), uint8
# Mask train_36.png: (2547, 3396), uint8
# Mask train_37.png: (2547, 3396), uint8
# Mask train_38.png: (2547, 3396), uint8
# Mask train_39.png: (2547, 3396), uint8
# Mask train_40.png: (2547, 3396), uint8
# Mask train_41.png: (2547, 3396), uint8
# Mask train_42.png: (2547, 3396), uint8
# Mask train_43.png: (2547, 3396), uint8
# Mask train_44.png: (2547, 3396), uint8
# Mask train_45.png: (2547, 3396), uint8
# Mask train_46.png: (2547, 3396), uint8
# Mask train_47.png: (2547, 3396), uint8
# Mask train_48.png: (2547, 3396), uint8
# Mask train_49.png: (2547, 3396), uint8
# Mask train_50.png: (2547, 3396), uint8
# Mask train_51.png: (2547, 3396), uint8
# Mask train_52.png: (2547, 3396), uint8
# Mask train_53.png: (2547, 3396), uint8
# Mask train_54.png: (2547, 3396), uint8
# Mask train_55.png: (2547, 3396), uint8
# Mask train_56.png: (2547, 3396), uint8
# Mask train_57.png: (2547, 3396), uint8
# Mask train_58.png: (2547, 3396), uint8
# Mask train_59.png: (2547, 3396), uint8

# %% [markdown]
# Загрузка масок с one-hot кодированием

# %%
for _, mask_p in train_img_mask_p:
    mask_one_hot = load_mask(mask_p, classes=classset, one_hot=True)
    print(f"Mask one-hot {mask_p.name}: {mask_one_hot.shape}, {mask_one_hot.dtype}")
# Out:
# Mask one-hot train_01.png: (2547, 3396, 7), float32
# Mask one-hot train_02.png: (2547, 3396, 7), float32
# Mask one-hot train_03.png: (2547, 3396, 7), float32
# Mask one-hot train_04.png: (2547, 3396, 7), float32
# Mask one-hot train_06.png: (2547, 3396, 7), float32
# Mask one-hot train_07.png: (2547, 3396, 7), float32
# Mask one-hot train_08.png: (2547, 3396, 7), float32
# Mask one-hot train_09.png: (2547, 3396, 7), float32
# Mask one-hot train_10.png: (2547, 3396, 7), float32
# Mask one-hot train_11.png: (2547, 3396, 7), float32
# Mask one-hot train_12.png: (2547, 3396, 7), float32
# Mask one-hot train_13.png: (2547, 3396, 7), float32
# Mask one-hot train_14.png: (2547, 3396, 7), float32
# Mask one-hot train_15.png: (2547, 3396, 7), float32
# Mask one-hot train_16.png: (2547, 3396, 7), float32
# Mask one-hot train_17.png: (2547, 3396, 7), float32
# Mask one-hot train_18.png: (2547, 3396, 7), float32
# Mask one-hot train_19.png: (2547, 3396, 7), float32
# Mask one-hot train_20.png: (2547, 3396, 7), float32
# Mask one-hot train_21.png: (2547, 3396, 7), float32
# Mask one-hot train_22.png: (2547, 3396, 7), float32
# Mask one-hot train_23.png: (2547, 3396, 7), float32
# Mask one-hot train_24.png: (2547, 3396, 7), float32
# Mask one-hot train_25.png: (2547, 3396, 7), float32
# Mask one-hot train_26.png: (2547, 3396, 7), float32
# Mask one-hot train_27.png: (2547, 3396, 7), float32
# Mask one-hot train_28.png: (2547, 3396, 7), float32
# Mask one-hot train_29.png: (2547, 3396, 7), float32
# Mask one-hot train_30.png: (2547, 3396, 7), float32
# Mask one-hot train_31.png: (2547, 3396, 7), float32
# Mask one-hot train_32.png: (2547, 3396, 7), float32
# Mask one-hot train_33.png: (2547, 3396, 7), float32
# Mask one-hot train_34.png: (2547, 3396, 7), float32
# Mask one-hot train_35.png: (2547, 3396, 7), float32
# Mask one-hot train_36.png: (2547, 3396, 7), float32
# Mask one-hot train_37.png: (2547, 3396, 7), float32
# Mask one-hot train_38.png: (2547, 3396, 7), float32
# Mask one-hot train_39.png: (2547, 3396, 7), float32
# Mask one-hot train_40.png: (2547, 3396, 7), float32
# Mask one-hot train_41.png: (2547, 3396, 7), float32
# Mask one-hot train_42.png: (2547, 3396, 7), float32
# Mask one-hot train_43.png: (2547, 3396, 7), float32
# Mask one-hot train_44.png: (2547, 3396, 7), float32
# Mask one-hot train_45.png: (2547, 3396, 7), float32
# Mask one-hot train_46.png: (2547, 3396, 7), float32
# Mask one-hot train_47.png: (2547, 3396, 7), float32
# Mask one-hot train_48.png: (2547, 3396, 7), float32
# Mask one-hot train_49.png: (2547, 3396, 7), float32
# Mask one-hot train_50.png: (2547, 3396, 7), float32
# Mask one-hot train_51.png: (2547, 3396, 7), float32
# Mask one-hot train_52.png: (2547, 3396, 7), float32
# Mask one-hot train_53.png: (2547, 3396, 7), float32
# Mask one-hot train_54.png: (2547, 3396, 7), float32
# Mask one-hot train_55.png: (2547, 3396, 7), float32
# Mask one-hot train_56.png: (2547, 3396, 7), float32
# Mask one-hot train_57.png: (2547, 3396, 7), float32
# Mask one-hot train_58.png: (2547, 3396, 7), float32
# Mask one-hot train_59.png: (2547, 3396, 7), float32

# %% [markdown]
# Загрузка цветных масок

# %%
for img_p, _ in train_img_mask_p:
    mask_colored_path = ds_path / "masks_colored_png" / "train" / f"{img_p.stem}.png"
    mask_colored = load_image(mask_colored_path, normalize=False)
    print(f"Colored mask {mask_colored_path.name}: {mask_colored.shape}, {mask_colored.dtype}")
# Out:
# Colored mask train_01.png: (2547, 3396, 3), uint8
# Colored mask train_02.png: (2547, 3396, 3), uint8
# Colored mask train_03.png: (2547, 3396, 3), uint8
# Colored mask train_04.png: (2547, 3396, 3), uint8
# Colored mask train_06.png: (2547, 3396, 3), uint8
# Colored mask train_07.png: (2547, 3396, 3), uint8
# Colored mask train_08.png: (2547, 3396, 3), uint8
# Colored mask train_09.png: (2547, 3396, 3), uint8
# Colored mask train_10.png: (2547, 3396, 3), uint8
# Colored mask train_11.png: (2547, 3396, 3), uint8
# Colored mask train_12.png: (2547, 3396, 3), uint8
# Colored mask train_13.png: (2547, 3396, 3), uint8
# Colored mask train_14.png: (2547, 3396, 3), uint8
# Colored mask train_15.png: (2547, 3396, 3), uint8
# Colored mask train_16.png: (2547, 3396, 3), uint8
# Colored mask train_17.png: (2547, 3396, 3), uint8
# Colored mask train_18.png: (2547, 3396, 3), uint8
# Colored mask train_19.png: (2547, 3396, 3), uint8
# Colored mask train_20.png: (2547, 3396, 3), uint8
# Colored mask train_21.png: (2547, 3396, 3), uint8
# Colored mask train_22.png: (2547, 3396, 3), uint8
# Colored mask train_23.png: (2547, 3396, 3), uint8
# Colored mask train_24.png: (2547, 3396, 3), uint8
# Colored mask train_25.png: (2547, 3396, 3), uint8
# Colored mask train_26.png: (2547, 3396, 3), uint8
# Colored mask train_27.png: (2547, 3396, 3), uint8
# Colored mask train_28.png: (2547, 3396, 3), uint8
# Colored mask train_29.png: (2547, 3396, 3), uint8
# Colored mask train_30.png: (2547, 3396, 3), uint8
# Colored mask train_31.png: (2547, 3396, 3), uint8
# Colored mask train_32.png: (2547, 3396, 3), uint8
# Colored mask train_33.png: (2547, 3396, 3), uint8
# Colored mask train_34.png: (2547, 3396, 3), uint8
# Colored mask train_35.png: (2547, 3396, 3), uint8
# Colored mask train_36.png: (2547, 3396, 3), uint8
# Colored mask train_37.png: (2547, 3396, 3), uint8
# Colored mask train_38.png: (2547, 3396, 3), uint8
# Colored mask train_39.png: (2547, 3396, 3), uint8
# Colored mask train_40.png: (2547, 3396, 3), uint8
# Colored mask train_41.png: (2547, 3396, 3), uint8
# Colored mask train_42.png: (2547, 3396, 3), uint8
# Colored mask train_43.png: (2547, 3396, 3), uint8
# Colored mask train_44.png: (2547, 3396, 3), uint8
# Colored mask train_45.png: (2547, 3396, 3), uint8
# Colored mask train_46.png: (2547, 3396, 3), uint8
# Colored mask train_47.png: (2547, 3396, 3), uint8
# Colored mask train_48.png: (2547, 3396, 3), uint8
# Colored mask train_49.png: (2547, 3396, 3), uint8
# Colored mask train_50.png: (2547, 3396, 3), uint8
# Colored mask train_51.png: (2547, 3396, 3), uint8
# Colored mask train_52.png: (2547, 3396, 3), uint8
# Colored mask train_53.png: (2547, 3396, 3), uint8
# Colored mask train_54.png: (2547, 3396, 3), uint8
# Colored mask train_55.png: (2547, 3396, 3), uint8
# Colored mask train_56.png: (2547, 3396, 3), uint8
# Colored mask train_57.png: (2547, 3396, 3), uint8
# Colored mask train_58.png: (2547, 3396, 3), uint8
# Colored mask train_59.png: (2547, 3396, 3), uint8

# %% [markdown]
# Функция для загрузки и предобработки изображений и масок

# %%
def load_and_preprocess(img_path, mask_path, classes, img_size=(256, 256)):
    img = load_image(img_path, normalize=True)
    img = tf.image.resize(img, img_size)

    mask = load_mask(mask_path, classes=classes, one_hot=False)
    mask = tf.image.resize(mask[..., np.newaxis], img_size, method='nearest')
    mask = to_categorical(mask, num_classes=len(classes))

    return img, mask

# %% [markdown]
# Унаследованный класс от GeoSegmModel, метод сегментации - нейронная сеть U-Net

# %%
class UNetSegmModel(GeoSegmModel):
    def __init__(self, classes: ClassSet, input_size=(256, 256, 3), save_path="unet_model"):
        super().__init__()
        self.classes = classes
        self.input_size = input_size
        self.save_path = Path(save_path)
        self.model = self._build_model()

    def _build_model(self):
        inputs = Input(self.input_size)

        conv1 = Conv2D(64, 3, activation='relu', padding='same')(inputs)
        conv1 = Conv2D(64, 3, activation='relu', padding='same')(conv1)
        pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
        conv2 = Conv2D(128, 3, activation='relu', padding='same')(pool1)
        conv2 = Conv2D(128, 3, activation='relu', padding='same')(conv2)
        pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
        conv3 = Conv2D(256, 3, activation='relu', padding='same')(pool2)
        conv3 = Conv2D(256, 3, activation='relu', padding='same')(conv3)
        pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
        conv4 = Conv2D(512, 3, activation='relu', padding='same')(pool3)
        conv4 = Conv2D(512, 3, activation='relu', padding='same')(conv4)

        up5 = concatenate([UpSampling2D(size=(2, 2))(conv4), conv3], axis=-1)
        conv5 = Conv2D(256, 3, activation='relu', padding='same')(up5)
        conv5 = Conv2D(256, 3, activation='relu', padding='same')(conv5)
        up6 = concatenate([UpSampling2D(size=(2, 2))(conv5), conv2], axis=-1)
        conv6 = Conv2D(128, 3, activation='relu', padding='same')(up6)
        conv6 = Conv2D(128, 3, activation='relu', padding='same')(conv6)
        up7 = concatenate([UpSampling2D(size=(2, 2))(conv6), conv1], axis=-1)
        conv7 = Conv2D(64, 3, activation='relu', padding='same')(up7)
        conv7 = Conv2D(64, 3, activation='relu', padding='same')(conv7)

        outputs = Conv2D(len(self.classes), 1, activation='softmax')(conv7)

        model = Model(inputs=[inputs], outputs=[outputs])
        model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
        return model

    def train(self, img_mask_paths, epochs=20, batch_size=4, validation_split=0.1, **kwargs):
        train_data = [load_and_preprocess(img_p, mask_p, self.classes) for img_p, mask_p in tqdm(img_mask_paths, desc="Loading data")]
        train_images, train_masks = zip(*train_data)
        train_images = np.array(train_images)
        train_masks = np.array(train_masks)

        self.model.fit([train_images], [train_masks], batch_size=batch_size, epochs=epochs, validation_split=validation_split)

        self.save()

    def predict_image(self, image: np.ndarray) -> np.ndarray:
        img_resized = tf.image.resize(image, self.input_size[:2])
        pred = self.model.predict(np.expand_dims(img_resized, axis=0))
        pred = np.argmax(pred[0], axis=-1)
        return pred.astype(np.uint8)

    def save(self):
        self.save_path.mkdir(parents=True, exist_ok=True)
        self.model.save(self.save_path / "unet_model.keras")

    def load(self, saved_path: Path, **kwargs):
        if not saved_path.exists():
            raise FileNotFoundError(f"Model file not found at {saved_path}")
        self.model = load_model(saved_path / "unet_model.keras")

# %% [markdown]
# Обучение модели

# %%
model = UNetSegmModel(classes=classset, input_size=(256, 256, 3), save_path="unet_model")

model.train(train_img_mask_p, epochs=200, batch_size=8, validation_split=0.1)
# Out:
# Loading data: 100%|██████████| 58/58 [00:32<00:00,  1.77it/s]
# Epoch 1/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 81s 6s/step - accuracy: 0.2878 - loss: 3.1463 - val_accuracy: 0.3438 - val_loss: 1.9293
# Epoch 2/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 335ms/step - accuracy: 0.3057 - loss: 1.7832 - val_accuracy: 0.3515 - val_loss: 2.0551
# Epoch 3/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 345ms/step - accuracy: 0.4016 - loss: 1.4435 - val_accuracy: 0.3582 - val_loss: 1.7751
# Epoch 4/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 337ms/step - accuracy: 0.5407 - loss: 1.2612 - val_accuracy: 0.4854 - val_loss: 1.7893
# Epoch 5/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 336ms/step - accuracy: 0.6613 - loss: 1.1003 - val_accuracy: 0.4419 - val_loss: 2.0052
# Epoch 6/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 336ms/step - accuracy: 0.6560 - loss: 1.0465 - val_accuracy: 0.4682 - val_loss: 1.8772
# Epoch 7/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 335ms/step - accuracy: 0.7034 - loss: 0.9920 - val_accuracy: 0.4710 - val_loss: 1.8852
# Epoch 8/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 350ms/step - accuracy: 0.7238 - loss: 0.9609 - val_accuracy: 0.4408 - val_loss: 2.4714
# Epoch 9/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 339ms/step - accuracy: 0.6060 - loss: 1.1678 - val_accuracy: 0.4794 - val_loss: 2.1308
# Epoch 10/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 337ms/step - accuracy: 0.7538 - loss: 0.8598 - val_accuracy: 0.4925 - val_loss: 1.9461
# Epoch 11/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 346ms/step - accuracy: 0.7084 - loss: 0.9119 - val_accuracy: 0.4836 - val_loss: 2.0936
# Epoch 12/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 339ms/step - accuracy: 0.7086 - loss: 0.9051 - val_accuracy: 0.4830 - val_loss: 1.9741
# Epoch 13/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 341ms/step - accuracy: 0.7061 - loss: 0.9036 - val_accuracy: 0.4670 - val_loss: 1.9433
# Epoch 14/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 349ms/step - accuracy: 0.7462 - loss: 0.8609 - val_accuracy: 0.4971 - val_loss: 1.9202
# Epoch 15/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 339ms/step - accuracy: 0.7326 - loss: 0.8531 - val_accuracy: 0.4558 - val_loss: 2.0883
# Epoch 16/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 339ms/step - accuracy: 0.8057 - loss: 0.7076 - val_accuracy: 0.4847 - val_loss: 1.7292
# Epoch 17/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 346ms/step - accuracy: 0.7050 - loss: 0.9211 - val_accuracy: 0.4885 - val_loss: 2.3667
# Epoch 18/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 351ms/step - accuracy: 0.7495 - loss: 0.7848 - val_accuracy: 0.5056 - val_loss: 2.2697
# Epoch 19/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 351ms/step - accuracy: 0.7498 - loss: 0.8005 - val_accuracy: 0.4879 - val_loss: 2.4395
# Epoch 20/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 339ms/step - accuracy: 0.7232 - loss: 0.9005 - val_accuracy: 0.5048 - val_loss: 1.8778
# Epoch 21/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 348ms/step - accuracy: 0.7883 - loss: 0.6885 - val_accuracy: 0.4945 - val_loss: 2.0005
# Epoch 22/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 341ms/step - accuracy: 0.8146 - loss: 0.6339 - val_accuracy: 0.5052 - val_loss: 2.0230
# Epoch 23/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 343ms/step - accuracy: 0.8132 - loss: 0.6357 - val_accuracy: 0.5173 - val_loss: 1.7803
# Epoch 24/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 345ms/step - accuracy: 0.7803 - loss: 0.6936 - val_accuracy: 0.5215 - val_loss: 2.0510
# Epoch 25/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 351ms/step - accuracy: 0.8023 - loss: 0.6354 - val_accuracy: 0.5204 - val_loss: 1.8889
# Epoch 26/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 349ms/step - accuracy: 0.8024 - loss: 0.6179 - val_accuracy: 0.5211 - val_loss: 2.2173
# Epoch 27/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 351ms/step - accuracy: 0.7927 - loss: 0.6709 - val_accuracy: 0.5188 - val_loss: 2.0016
# Epoch 28/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 351ms/step - accuracy: 0.7955 - loss: 0.6365 - val_accuracy: 0.5182 - val_loss: 2.2360
# Epoch 29/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 357ms/step - accuracy: 0.8024 - loss: 0.6401 - val_accuracy: 0.5166 - val_loss: 1.8053
# Epoch 30/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 343ms/step - accuracy: 0.8084 - loss: 0.5917 - val_accuracy: 0.5133 - val_loss: 1.7759
# Epoch 31/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 343ms/step - accuracy: 0.8067 - loss: 0.6211 - val_accuracy: 0.4984 - val_loss: 1.9135
# Epoch 32/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 351ms/step - accuracy: 0.8110 - loss: 0.6151 - val_accuracy: 0.5231 - val_loss: 1.5978
# Epoch 33/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 346ms/step - accuracy: 0.8059 - loss: 0.6039 - val_accuracy: 0.5052 - val_loss: 1.6688
# Epoch 34/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 357ms/step - accuracy: 0.8394 - loss: 0.5323 - val_accuracy: 0.5246 - val_loss: 1.7092
# Epoch 35/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 353ms/step - accuracy: 0.8134 - loss: 0.5980 - val_accuracy: 0.5228 - val_loss: 1.6397
# Epoch 36/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 344ms/step - accuracy: 0.8212 - loss: 0.5630 - val_accuracy: 0.4876 - val_loss: 1.6191
# Epoch 37/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 350ms/step - accuracy: 0.7887 - loss: 0.6197 - val_accuracy: 0.5040 - val_loss: 1.7089
# Epoch 38/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 351ms/step - accuracy: 0.8294 - loss: 0.5374 - val_accuracy: 0.5253 - val_loss: 1.5763
# Epoch 39/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 350ms/step - accuracy: 0.8002 - loss: 0.6326 - val_accuracy: 0.5226 - val_loss: 1.6098
# Epoch 40/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 345ms/step - accuracy: 0.8077 - loss: 0.5957 - val_accuracy: 0.5205 - val_loss: 1.8949
# Epoch 41/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 345ms/step - accuracy: 0.8016 - loss: 0.5915 - val_accuracy: 0.5234 - val_loss: 1.4883
# Epoch 42/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 345ms/step - accuracy: 0.8004 - loss: 0.6258 - val_accuracy: 0.5106 - val_loss: 1.4435
# Epoch 43/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 353ms/step - accuracy: 0.8141 - loss: 0.5753 - val_accuracy: 0.4957 - val_loss: 1.5736
# Epoch 44/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 357ms/step - accuracy: 0.8224 - loss: 0.5384 - val_accuracy: 0.5243 - val_loss: 1.5203
# Epoch 45/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 346ms/step - accuracy: 0.8270 - loss: 0.5486 - val_accuracy: 0.5196 - val_loss: 1.8097
# Epoch 46/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 354ms/step - accuracy: 0.8237 - loss: 0.5493 - val_accuracy: 0.5093 - val_loss: 1.4290
# Epoch 47/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 344ms/step - accuracy: 0.7772 - loss: 0.6506 - val_accuracy: 0.5070 - val_loss: 2.1073
# Epoch 48/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 345ms/step - accuracy: 0.7804 - loss: 0.7682 - val_accuracy: 0.4981 - val_loss: 1.5574
# Epoch 49/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 350ms/step - accuracy: 0.7814 - loss: 0.6923 - val_accuracy: 0.5257 - val_loss: 1.4597
# Epoch 50/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 344ms/step - accuracy: 0.8215 - loss: 0.5577 - val_accuracy: 0.5214 - val_loss: 1.5834
# Epoch 51/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 354ms/step - accuracy: 0.8148 - loss: 0.5262 - val_accuracy: 0.5252 - val_loss: 1.4514
# Epoch 52/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 355ms/step - accuracy: 0.8133 - loss: 0.5593 - val_accuracy: 0.5139 - val_loss: 1.4094
# Epoch 53/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 355ms/step - accuracy: 0.8225 - loss: 0.5302 - val_accuracy: 0.5226 - val_loss: 1.4598
# Epoch 54/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 356ms/step - accuracy: 0.8422 - loss: 0.4570 - val_accuracy: 0.5214 - val_loss: 1.1994
# Epoch 55/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 357ms/step - accuracy: 0.8251 - loss: 0.4827 - val_accuracy: 0.5345 - val_loss: 1.1164
# Epoch 56/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 348ms/step - accuracy: 0.8159 - loss: 0.5420 - val_accuracy: 0.5363 - val_loss: 1.1190
# Epoch 57/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 347ms/step - accuracy: 0.8110 - loss: 0.5867 - val_accuracy: 0.5277 - val_loss: 1.4304
# Epoch 58/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 356ms/step - accuracy: 0.8395 - loss: 0.4892 - val_accuracy: 0.5193 - val_loss: 1.3224
# Epoch 59/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 353ms/step - accuracy: 0.8520 - loss: 0.4351 - val_accuracy: 0.5294 - val_loss: 1.1264
# Epoch 60/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 348ms/step - accuracy: 0.8189 - loss: 0.5445 - val_accuracy: 0.5280 - val_loss: 1.2803
# Epoch 61/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 355ms/step - accuracy: 0.8077 - loss: 0.5699 - val_accuracy: 0.5266 - val_loss: 1.3289
# Epoch 62/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 348ms/step - accuracy: 0.8371 - loss: 0.5203 - val_accuracy: 0.5314 - val_loss: 1.2265
# Epoch 63/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 355ms/step - accuracy: 0.8407 - loss: 0.5054 - val_accuracy: 0.4790 - val_loss: 1.6685
# Epoch 64/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 361ms/step - accuracy: 0.8043 - loss: 0.5725 - val_accuracy: 0.5344 - val_loss: 1.0021
# Epoch 65/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 349ms/step - accuracy: 0.8403 - loss: 0.5001 - val_accuracy: 0.5347 - val_loss: 1.2175
# Epoch 66/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 347ms/step - accuracy: 0.8311 - loss: 0.4849 - val_accuracy: 0.5034 - val_loss: 1.1328
# Epoch 67/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 348ms/step - accuracy: 0.8501 - loss: 0.4518 - val_accuracy: 0.5738 - val_loss: 0.9825
# Epoch 68/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 349ms/step - accuracy: 0.8721 - loss: 0.3919 - val_accuracy: 0.5611 - val_loss: 0.9081
# Epoch 69/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 359ms/step - accuracy: 0.8510 - loss: 0.4291 - val_accuracy: 0.5600 - val_loss: 0.8818
# Epoch 70/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 349ms/step - accuracy: 0.8347 - loss: 0.5304 - val_accuracy: 0.5376 - val_loss: 1.1178
# Epoch 71/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 350ms/step - accuracy: 0.8172 - loss: 0.5223 - val_accuracy: 0.5550 - val_loss: 1.0143
# Epoch 72/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 349ms/step - accuracy: 0.8559 - loss: 0.4342 - val_accuracy: 0.5398 - val_loss: 1.1067
# Epoch 73/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 357ms/step - accuracy: 0.8852 - loss: 0.3492 - val_accuracy: 0.5335 - val_loss: 1.2386
# Epoch 74/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 356ms/step - accuracy: 0.8613 - loss: 0.4219 - val_accuracy: 0.6281 - val_loss: 0.7765
# Epoch 75/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 352ms/step - accuracy: 0.8485 - loss: 0.4534 - val_accuracy: 0.5479 - val_loss: 0.8355
# Epoch 76/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 354ms/step - accuracy: 0.8699 - loss: 0.3875 - val_accuracy: 0.5993 - val_loss: 0.8035
# Epoch 77/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 364ms/step - accuracy: 0.8691 - loss: 0.3905 - val_accuracy: 0.5792 - val_loss: 0.8553
# Epoch 78/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 365ms/step - accuracy: 0.8727 - loss: 0.3927 - val_accuracy: 0.5392 - val_loss: 1.0936
# Epoch 79/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 367ms/step - accuracy: 0.8095 - loss: 0.5273 - val_accuracy: 0.7853 - val_loss: 0.7435
# Epoch 80/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 370ms/step - accuracy: 0.8701 - loss: 0.4326 - val_accuracy: 0.5515 - val_loss: 1.2867
# Epoch 81/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 368ms/step - accuracy: 0.8887 - loss: 0.3792 - val_accuracy: 0.5868 - val_loss: 0.9537
# Epoch 82/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 363ms/step - accuracy: 0.8351 - loss: 0.4838 - val_accuracy: 0.7171 - val_loss: 0.6325
# Epoch 83/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 358ms/step - accuracy: 0.8657 - loss: 0.4114 - val_accuracy: 0.6211 - val_loss: 1.1107
# Epoch 84/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 360ms/step - accuracy: 0.8531 - loss: 0.4322 - val_accuracy: 0.5475 - val_loss: 1.0767
# Epoch 85/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 358ms/step - accuracy: 0.8460 - loss: 0.4366 - val_accuracy: 0.5461 - val_loss: 1.2580
# Epoch 86/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 355ms/step - accuracy: 0.8673 - loss: 0.3989 - val_accuracy: 0.6028 - val_loss: 0.8558
# Epoch 87/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 370ms/step - accuracy: 0.8702 - loss: 0.4116 - val_accuracy: 0.6116 - val_loss: 0.8205
# Epoch 88/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 356ms/step - accuracy: 0.8982 - loss: 0.3007 - val_accuracy: 0.6319 - val_loss: 0.8235
# Epoch 89/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 366ms/step - accuracy: 0.8970 - loss: 0.3205 - val_accuracy: 0.5658 - val_loss: 0.9983
# Epoch 90/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 359ms/step - accuracy: 0.8823 - loss: 0.3674 - val_accuracy: 0.6016 - val_loss: 0.9091
# Epoch 91/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 363ms/step - accuracy: 0.8058 - loss: 0.5551 - val_accuracy: 0.6486 - val_loss: 0.7218
# Epoch 92/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 362ms/step - accuracy: 0.8582 - loss: 0.4019 - val_accuracy: 0.5702 - val_loss: 1.0423
# Epoch 93/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 354ms/step - accuracy: 0.8884 - loss: 0.3491 - val_accuracy: 0.5884 - val_loss: 0.9416
# Epoch 94/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 365ms/step - accuracy: 0.9031 - loss: 0.3038 - val_accuracy: 0.7045 - val_loss: 0.6980
# Epoch 95/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 366ms/step - accuracy: 0.8742 - loss: 0.3714 - val_accuracy: 0.6397 - val_loss: 0.8917
# Epoch 96/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 355ms/step - accuracy: 0.8816 - loss: 0.3557 - val_accuracy: 0.6598 - val_loss: 0.6685
# Epoch 97/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 360ms/step - accuracy: 0.8902 - loss: 0.3511 - val_accuracy: 0.6911 - val_loss: 0.8002
# Epoch 98/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 357ms/step - accuracy: 0.9006 - loss: 0.2992 - val_accuracy: 0.6269 - val_loss: 0.7647
# Epoch 99/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 355ms/step - accuracy: 0.9091 - loss: 0.2974 - val_accuracy: 0.6721 - val_loss: 0.7184
# Epoch 100/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 354ms/step - accuracy: 0.9087 - loss: 0.2698 - val_accuracy: 0.6410 - val_loss: 0.7448
# Epoch 101/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 362ms/step - accuracy: 0.9082 - loss: 0.2855 - val_accuracy: 0.8082 - val_loss: 0.6442
# Epoch 102/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 356ms/step - accuracy: 0.9151 - loss: 0.2624 - val_accuracy: 0.7576 - val_loss: 0.7579
# Epoch 103/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 358ms/step - accuracy: 0.9110 - loss: 0.2827 - val_accuracy: 0.6314 - val_loss: 0.7494
# Epoch 104/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 365ms/step - accuracy: 0.8856 - loss: 0.3384 - val_accuracy: 0.6389 - val_loss: 0.7022
# Epoch 105/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 364ms/step - accuracy: 0.8968 - loss: 0.3318 - val_accuracy: 0.7158 - val_loss: 0.6661
# Epoch 106/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 360ms/step - accuracy: 0.8681 - loss: 0.3810 - val_accuracy: 0.6779 - val_loss: 0.7742
# Epoch 107/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 358ms/step - accuracy: 0.8878 - loss: 0.3192 - val_accuracy: 0.6378 - val_loss: 1.0314
# Epoch 108/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 367ms/step - accuracy: 0.8842 - loss: 0.3743 - val_accuracy: 0.6996 - val_loss: 0.6602
# Epoch 109/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 373ms/step - accuracy: 0.9058 - loss: 0.3032 - val_accuracy: 0.6526 - val_loss: 0.9407
# Epoch 110/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 365ms/step - accuracy: 0.8916 - loss: 0.3124 - val_accuracy: 0.6980 - val_loss: 0.8902
# Epoch 111/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 360ms/step - accuracy: 0.8842 - loss: 0.3363 - val_accuracy: 0.7587 - val_loss: 0.6684
# Epoch 112/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 357ms/step - accuracy: 0.8990 - loss: 0.3134 - val_accuracy: 0.8423 - val_loss: 0.5283
# Epoch 113/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 373ms/step - accuracy: 0.9168 - loss: 0.2705 - val_accuracy: 0.8230 - val_loss: 0.5900
# Epoch 114/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 363ms/step - accuracy: 0.9205 - loss: 0.2674 - val_accuracy: 0.6193 - val_loss: 0.7807
# Epoch 115/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 361ms/step - accuracy: 0.9280 - loss: 0.2294 - val_accuracy: 0.6898 - val_loss: 0.6454
# Epoch 116/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 372ms/step - accuracy: 0.9100 - loss: 0.2708 - val_accuracy: 0.7989 - val_loss: 0.6970
# Epoch 117/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 361ms/step - accuracy: 0.9309 - loss: 0.2268 - val_accuracy: 0.8558 - val_loss: 0.5197
# Epoch 118/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 355ms/step - accuracy: 0.9288 - loss: 0.2285 - val_accuracy: 0.8083 - val_loss: 0.5358
# Epoch 119/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 358ms/step - accuracy: 0.9148 - loss: 0.2511 - val_accuracy: 0.8566 - val_loss: 0.4712
# Epoch 120/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 372ms/step - accuracy: 0.9315 - loss: 0.2124 - val_accuracy: 0.8432 - val_loss: 0.5201
# Epoch 121/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 356ms/step - accuracy: 0.9368 - loss: 0.2061 - val_accuracy: 0.8362 - val_loss: 0.5282
# Epoch 122/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 366ms/step - accuracy: 0.9406 - loss: 0.1980 - val_accuracy: 0.8670 - val_loss: 0.4814
# Epoch 123/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 360ms/step - accuracy: 0.9438 - loss: 0.1790 - val_accuracy: 0.8906 - val_loss: 0.4481
# Epoch 124/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 365ms/step - accuracy: 0.9033 - loss: 0.2821 - val_accuracy: 0.7082 - val_loss: 1.0810
# Epoch 125/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 364ms/step - accuracy: 0.9009 - loss: 0.3094 - val_accuracy: 0.6893 - val_loss: 0.7864
# Epoch 126/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 364ms/step - accuracy: 0.8947 - loss: 0.3159 - val_accuracy: 0.7300 - val_loss: 0.6737
# Epoch 127/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 369ms/step - accuracy: 0.8905 - loss: 0.3222 - val_accuracy: 0.7749 - val_loss: 0.6685
# Epoch 128/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 358ms/step - accuracy: 0.9260 - loss: 0.2408 - val_accuracy: 0.8201 - val_loss: 0.5926
# Epoch 129/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 365ms/step - accuracy: 0.9366 - loss: 0.2105 - val_accuracy: 0.7050 - val_loss: 0.8280
# Epoch 130/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 360ms/step - accuracy: 0.9311 - loss: 0.2283 - val_accuracy: 0.7891 - val_loss: 0.5638
# Epoch 131/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 367ms/step - accuracy: 0.9325 - loss: 0.2159 - val_accuracy: 0.8300 - val_loss: 0.5790
# Epoch 132/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 365ms/step - accuracy: 0.9034 - loss: 0.2644 - val_accuracy: 0.8214 - val_loss: 0.4924
# Epoch 133/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 356ms/step - accuracy: 0.9002 - loss: 0.2855 - val_accuracy: 0.8773 - val_loss: 0.4194
# Epoch 134/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 358ms/step - accuracy: 0.9205 - loss: 0.2428 - val_accuracy: 0.7379 - val_loss: 0.8059
# Epoch 135/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 362ms/step - accuracy: 0.9239 - loss: 0.2417 - val_accuracy: 0.8145 - val_loss: 0.5953
# Epoch 136/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 357ms/step - accuracy: 0.9340 - loss: 0.2112 - val_accuracy: 0.8495 - val_loss: 0.5162
# Epoch 137/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 367ms/step - accuracy: 0.9442 - loss: 0.1826 - val_accuracy: 0.8412 - val_loss: 0.5215
# Epoch 138/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 358ms/step - accuracy: 0.9462 - loss: 0.1762 - val_accuracy: 0.8205 - val_loss: 0.5156
# Epoch 139/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 365ms/step - accuracy: 0.9379 - loss: 0.1935 - val_accuracy: 0.8020 - val_loss: 0.7212
# Epoch 140/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 369ms/step - accuracy: 0.9425 - loss: 0.1830 - val_accuracy: 0.7907 - val_loss: 0.6194
# Epoch 141/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 361ms/step - accuracy: 0.9430 - loss: 0.1782 - val_accuracy: 0.7522 - val_loss: 0.9858
# Epoch 142/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 364ms/step - accuracy: 0.9459 - loss: 0.1736 - val_accuracy: 0.7932 - val_loss: 0.7946
# Epoch 143/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 361ms/step - accuracy: 0.9472 - loss: 0.1694 - val_accuracy: 0.8268 - val_loss: 0.5544
# Epoch 144/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 369ms/step - accuracy: 0.9468 - loss: 0.1754 - val_accuracy: 0.7691 - val_loss: 0.7457
# Epoch 145/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 358ms/step - accuracy: 0.9542 - loss: 0.1460 - val_accuracy: 0.8209 - val_loss: 0.6637
# Epoch 146/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 356ms/step - accuracy: 0.9479 - loss: 0.1583 - val_accuracy: 0.7433 - val_loss: 0.8889
# Epoch 147/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 358ms/step - accuracy: 0.9423 - loss: 0.1840 - val_accuracy: 0.7964 - val_loss: 0.6121
# Epoch 148/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 372ms/step - accuracy: 0.9456 - loss: 0.1751 - val_accuracy: 0.8044 - val_loss: 0.7052
# Epoch 149/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 368ms/step - accuracy: 0.9499 - loss: 0.1582 - val_accuracy: 0.7524 - val_loss: 0.7451
# Epoch 150/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 358ms/step - accuracy: 0.9523 - loss: 0.1536 - val_accuracy: 0.6911 - val_loss: 0.8164
# Epoch 151/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 365ms/step - accuracy: 0.9595 - loss: 0.1321 - val_accuracy: 0.6819 - val_loss: 0.9298
# Epoch 152/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 355ms/step - accuracy: 0.9594 - loss: 0.1287 - val_accuracy: 0.7586 - val_loss: 0.6982
# Epoch 153/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 367ms/step - accuracy: 0.9570 - loss: 0.1364 - val_accuracy: 0.7214 - val_loss: 0.8342
# Epoch 154/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 370ms/step - accuracy: 0.9605 - loss: 0.1270 - val_accuracy: 0.7198 - val_loss: 0.8700
# Epoch 155/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 357ms/step - accuracy: 0.9609 - loss: 0.1217 - val_accuracy: 0.7394 - val_loss: 0.7490
# Epoch 156/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 356ms/step - accuracy: 0.9576 - loss: 0.1350 - val_accuracy: 0.6762 - val_loss: 1.2006
# Epoch 157/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 359ms/step - accuracy: 0.9560 - loss: 0.1388 - val_accuracy: 0.7501 - val_loss: 0.7714
# Epoch 158/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 362ms/step - accuracy: 0.9539 - loss: 0.1423 - val_accuracy: 0.7496 - val_loss: 0.8016
# Epoch 159/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 366ms/step - accuracy: 0.9641 - loss: 0.1141 - val_accuracy: 0.6926 - val_loss: 0.9259
# Epoch 160/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 368ms/step - accuracy: 0.9656 - loss: 0.1095 - val_accuracy: 0.7315 - val_loss: 0.8559
# Epoch 161/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 364ms/step - accuracy: 0.9619 - loss: 0.1204 - val_accuracy: 0.6841 - val_loss: 1.0278
# Epoch 162/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 362ms/step - accuracy: 0.9664 - loss: 0.1057 - val_accuracy: 0.6988 - val_loss: 1.0321
# Epoch 163/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 358ms/step - accuracy: 0.9661 - loss: 0.1061 - val_accuracy: 0.7340 - val_loss: 0.8404
# Epoch 164/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 360ms/step - accuracy: 0.9631 - loss: 0.1149 - val_accuracy: 0.7029 - val_loss: 0.9883
# Epoch 165/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 360ms/step - accuracy: 0.9038 - loss: 0.3111 - val_accuracy: 0.6117 - val_loss: 2.0747
# Epoch 166/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 368ms/step - accuracy: 0.8869 - loss: 0.3555 - val_accuracy: 0.5064 - val_loss: 1.2127
# Epoch 167/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 373ms/step - accuracy: 0.8957 - loss: 0.3483 - val_accuracy: 0.5789 - val_loss: 1.2593
# Epoch 168/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 355ms/step - accuracy: 0.8514 - loss: 0.4268 - val_accuracy: 0.6745 - val_loss: 0.8345
# Epoch 169/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 364ms/step - accuracy: 0.8133 - loss: 0.5731 - val_accuracy: 0.6550 - val_loss: 0.8593
# Epoch 170/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 359ms/step - accuracy: 0.8683 - loss: 0.4329 - val_accuracy: 0.5028 - val_loss: 1.6512
# Epoch 171/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 355ms/step - accuracy: 0.8555 - loss: 0.4843 - val_accuracy: 0.5806 - val_loss: 0.9823
# Epoch 172/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 356ms/step - accuracy: 0.8791 - loss: 0.3563 - val_accuracy: 0.7957 - val_loss: 0.7236
# Epoch 173/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 367ms/step - accuracy: 0.9002 - loss: 0.3144 - val_accuracy: 0.7690 - val_loss: 0.7219
# Epoch 174/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 367ms/step - accuracy: 0.9145 - loss: 0.2710 - val_accuracy: 0.7310 - val_loss: 0.7541
# Epoch 175/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 354ms/step - accuracy: 0.9000 - loss: 0.2975 - val_accuracy: 0.8396 - val_loss: 0.5239
# Epoch 176/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 365ms/step - accuracy: 0.9105 - loss: 0.2715 - val_accuracy: 0.6916 - val_loss: 1.0394
# Epoch 177/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 365ms/step - accuracy: 0.9172 - loss: 0.2618 - val_accuracy: 0.7209 - val_loss: 1.0519
# Epoch 178/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 367ms/step - accuracy: 0.9260 - loss: 0.2319 - val_accuracy: 0.7099 - val_loss: 0.6511
# Epoch 179/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 366ms/step - accuracy: 0.9226 - loss: 0.2523 - val_accuracy: 0.7987 - val_loss: 0.6796
# Epoch 180/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 368ms/step - accuracy: 0.9289 - loss: 0.2238 - val_accuracy: 0.6004 - val_loss: 1.7358
# Epoch 181/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 368ms/step - accuracy: 0.9247 - loss: 0.2276 - val_accuracy: 0.6911 - val_loss: 0.7487
# Epoch 182/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 355ms/step - accuracy: 0.9351 - loss: 0.1991 - val_accuracy: 0.6905 - val_loss: 0.8633
# Epoch 183/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 362ms/step - accuracy: 0.9331 - loss: 0.2004 - val_accuracy: 0.6623 - val_loss: 1.1172
# Epoch 184/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 362ms/step - accuracy: 0.9341 - loss: 0.2068 - val_accuracy: 0.7290 - val_loss: 0.6894
# Epoch 185/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 363ms/step - accuracy: 0.9443 - loss: 0.1781 - val_accuracy: 0.7028 - val_loss: 0.7601
# Epoch 186/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 359ms/step - accuracy: 0.9488 - loss: 0.1632 - val_accuracy: 0.7079 - val_loss: 0.8100
# Epoch 187/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 364ms/step - accuracy: 0.9535 - loss: 0.1479 - val_accuracy: 0.7394 - val_loss: 0.7091
# Epoch 188/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 369ms/step - accuracy: 0.9575 - loss: 0.1347 - val_accuracy: 0.7264 - val_loss: 0.7588
# Epoch 189/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 363ms/step - accuracy: 0.9553 - loss: 0.1359 - val_accuracy: 0.7047 - val_loss: 0.7986
# Epoch 190/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 358ms/step - accuracy: 0.9609 - loss: 0.1219 - val_accuracy: 0.7402 - val_loss: 0.7416
# Epoch 191/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 366ms/step - accuracy: 0.9624 - loss: 0.1178 - val_accuracy: 0.7227 - val_loss: 0.8166
# Epoch 192/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 356ms/step - accuracy: 0.9631 - loss: 0.1139 - val_accuracy: 0.7279 - val_loss: 0.8397
# Epoch 193/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 355ms/step - accuracy: 0.9607 - loss: 0.1236 - val_accuracy: 0.7553 - val_loss: 0.8150
# Epoch 194/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 359ms/step - accuracy: 0.9590 - loss: 0.1290 - val_accuracy: 0.6659 - val_loss: 1.0886
# Epoch 195/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 365ms/step - accuracy: 0.9613 - loss: 0.1191 - val_accuracy: 0.7492 - val_loss: 0.7589
# Epoch 196/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 364ms/step - accuracy: 0.9618 - loss: 0.1162 - val_accuracy: 0.7547 - val_loss: 0.8860
# Epoch 197/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 358ms/step - accuracy: 0.9630 - loss: 0.1171 - val_accuracy: 0.6877 - val_loss: 1.1355
# Epoch 198/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 356ms/step - accuracy: 0.9611 - loss: 0.1230 - val_accuracy: 0.7331 - val_loss: 0.9083
# Epoch 199/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 358ms/step - accuracy: 0.9680 - loss: 0.0989 - val_accuracy: 0.7111 - val_loss: 0.9463
# Epoch 200/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 365ms/step - accuracy: 0.9673 - loss: 0.1024 - val_accuracy: 0.7407 - val_loss: 0.8503

# %% [markdown]
# Тестирование

# %%
from petroscope.segmentation.eval import SegmDetailedTester
from tensorflow.keras.utils import to_categorical

tester = SegmDetailedTester(
    Path("output"),
    classes=classset,
    void_pad=0,
    void_border_width=4,
    vis_plots=False,
    vis_segmentation=True,
)

for img_p, mask_p in test_img_mask_p:
    img = load_image(img_p, normalize=True)

    pred = model.predict_image(img)
    print(f"Pred shape: {pred.shape}")

    mask = load_mask(mask_p, classes=classset, one_hot=False)
    mask_resized = tf.image.resize(mask[..., np.newaxis], (256, 256), method='nearest')
    mask_resized = mask_resized[..., 0].numpy().astype(np.uint8)
    print(f"Mask resized shape: {mask_resized.shape}")

    pred_one_hot = to_categorical(pred, num_classes=len(classset.classes))
    mask_one_hot = to_categorical(mask_resized, num_classes=len(classset.classes))
    print(f"Pred one-hot shape: {pred_one_hot.shape}")
    print(f"Mask one-hot shape: {mask_one_hot.shape}")

    metrics = tester.eval.evaluate(pred_one_hot, gt=mask_one_hot)
    metrics_void = tester.eval_void.evaluate(pred_one_hot, gt=mask_one_hot)

    print(f"Metrics for {img_p.name}:\n{metrics}")
    print(f"Metrics with void borders for {img_p.name}:\n{metrics_void}")
    print("-" * 50)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(1, 256, 256, 3))
#   warnings.warn(msg)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Pred shape: (256, 256)
# Mask resized shape: (256, 256)
# Pred one-hot shape: (256, 256, 7)
# Mask one-hot shape: (256, 256, 7)
# Metrics for test_01.jpg:
# 	 iou [soft]:
# 		 bg: 0.8814 [0.8814]
# 		 brt: 0.0010 [0.0010]
# 		 ccp/kub: 0.7368 [0.7368]
# 		 gl: 0.1642 [0.1642]
# 		 py/mrc: 0.9581 [0.9581]
# 		 sph: 0.7849 [0.7849]
# 		 tnt/ttr: 0.0074 [0.0074]
# 	 mean iou [soft]: 0.5048 [0.5048]
# 	 acc: 0.9280
#
# Metrics with void borders for test_01.jpg:
# 	 iou [soft]:
# 		 bg: 0.8814 [0.8814]
# 		 brt: 0.0010 [0.0010]
# 		 ccp/kub: 0.7368 [0.7368]
# 		 gl: 0.1642 [0.1642]
# 		 py/mrc: 0.9581 [0.9581]
# 		 sph: 0.7849 [0.7849]
# 		 tnt/ttr: 0.0074 [0.0074]
# 	 mean iou [soft]: 0.5048 [0.5048]
# 	 acc: 0.9280
#
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Pred shape: (256, 256)
# Mask resized shape: (256, 256)
# Pred one-hot shape: (256, 256, 7)
# Mask one-hot shape: (256, 256, 7)
# Metrics for test_02.jpg:
# 	 iou [soft]:
# 		 bg: 0.7972 [0.7972]
# 		 brt: 1.0000 [1.0000]
# 		 ccp/kub: 0.1273 [0.1273]
# 		 gl: 0.1905 [0.1905]
# 		 py/mrc: 0.9518 [0.9518]
# 		 sph: 0.5996 [0.5996]
# 		 tnt/ttr: 0.0000 [0.0000]
# 	 mean iou [soft]: 0.5238 [0.5238]
# 	 acc: 0.8822
#
# Metrics with void borders for test_02.jpg:
# 	 iou [soft]:
# 		 bg: 0.7972 [0.7972]
# 		 brt: 1.0000 [1.0000]
# 		 ccp/kub: 0.1273 [0.1273]
# 		 gl: 0.1905 [0.1905]
# 		 py/mrc: 0.9518 [0.9518]
# 		 sph: 0.5996 [0.5996]
# 		 tnt/ttr: 0.0000 [0.0000]
# 	 mean iou [soft]: 0.5238 [0.5238]
# 	 acc: 0.8822
#
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Pred shape: (256, 256)
# Mask resized shape: (256, 256)
# Pred one-hot shape: (256, 256, 7)
# Mask one-hot shape: (256, 256, 7)
# Metrics for test_03.jpg:
# 	 iou [soft]:
# 		 bg: 0.9119 [0.9119]
# 		 brt: 1.0000 [1.0000]
# 		 ccp/kub: 0.0000 [0.0000]
# 		 gl: 0.6266 [0.6266]
# 		 py/mrc: 0.9352 [0.9352]
# 		 sph: 0.8856 [0.8856]
# 		 tnt/ttr: 0.8157 [0.8157]
# 	 mean iou [soft]: 0.7393 [0.7393]
# 	 acc: 0.9227
#
# Metrics with void borders for test_03.jpg:
# 	 iou [soft]:
# 		 bg: 0.9119 [0.9119]
# 		 brt: 1.0000 [1.0000]
# 		 ccp/kub: 0.0000 [0.0000]
# 		 gl: 0.6266 [0.6266]
# 		 py/mrc: 0.9352 [0.9352]
# 		 sph: 0.8856 [0.8856]
# 		 tnt/ttr: 0.8157 [0.8157]
# 	 mean iou [soft]: 0.7393 [0.7393]
# 	 acc: 0.9227
#
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Pred shape: (256, 256)
# Mask resized shape: (256, 256)
# Pred one-hot shape: (256, 256, 7)
# Mask one-hot shape: (256, 256, 7)
# Metrics for test_04.jpg:
# 	 iou [soft]:
# 		 bg: 0.8653 [0.8653]
# 		 brt: 0.0000 [0.0000]
# 		 ccp/kub: 0.0000 [0.0000]
# 		 gl: 0.4522 [0.4522]
# 		 py/mrc: 0.8358 [0.8358]
# 		 sph: 0.3857 [0.3857]
# 		 tnt/ttr: 0.0000 [0.0000]
# 	 mean iou [soft]: 0.3627 [0.3627]
# 	 acc: 0.8629
#
# Metrics with void borders for test_04.jpg:
# 	 iou [soft]:
# 		 bg: 0.8653 [0.8653]
# 		 brt: 0.0000 [0.0000]
# 		 ccp/kub: 0.0000 [0.0000]
# 		 gl: 0.4522 [0.4522]
# 		 py/mrc: 0.8358 [0.8358]
# 		 sph: 0.3857 [0.3857]
# 		 tnt/ttr: 0.0000 [0.0000]
# 	 mean iou [soft]: 0.3627 [0.3627]
# 	 acc: 0.8629
#
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Pred shape: (256, 256)
# Mask resized shape: (256, 256)
# Pred one-hot shape: (256, 256, 7)
# Mask one-hot shape: (256, 256, 7)
# Metrics for test_05.jpg:
# 	 iou [soft]:
# 		 bg: 0.7699 [0.7699]
# 		 brt: 0.0003 [0.0003]
# 		 ccp/kub: 0.6641 [0.6641]
# 		 gl: 0.3029 [0.3029]
# 		 py/mrc: 0.9723 [0.9723]
# 		 sph: 0.9186 [0.9186]
# 		 tnt/ttr: 0.0000 [0.0000]
# 	 mean iou [soft]: 0.5183 [0.5183]
# 	 acc: 0.9520
#
# Metrics with void borders for test_05.jpg:
# 	 iou [soft]:
# 		 bg: 0.7699 [0.7699]
# 		 brt: 0.0003 [0.0003]
# 		 ccp/kub: 0.6641 [0.6641]
# 		 gl: 0.3029 [0.3029]
# 		 py/mrc: 0.9723 [0.9723]
# 		 sph: 0.9186 [0.9186]
# 		 tnt/ttr: 0.0000 [0.0000]
# 	 mean iou [soft]: 0.5183 [0.5183]
# 	 acc: 0.9520
#
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Pred shape: (256, 256)
# Mask resized shape: (256, 256)
# Pred one-hot shape: (256, 256, 7)
# Mask one-hot shape: (256, 256, 7)
# Metrics for test_06.jpg:
# 	 iou [soft]:
# 		 bg: 0.8297 [0.8297]
# 		 brt: 0.0000 [0.0000]
# 		 ccp/kub: 0.7301 [0.7301]
# 		 gl: 0.2444 [0.2444]
# 		 py/mrc: 0.9380 [0.9380]
# 		 sph: 0.7518 [0.7518]
# 		 tnt/ttr: 0.1455 [0.1455]
# 	 mean iou [soft]: 0.5199 [0.5199]
# 	 acc: 0.8652
#
# Metrics with void borders for test_06.jpg:
# 	 iou [soft]:
# 		 bg: 0.8297 [0.8297]
# 		 brt: 0.0000 [0.0000]
# 		 ccp/kub: 0.7301 [0.7301]
# 		 gl: 0.2444 [0.2444]
# 		 py/mrc: 0.9380 [0.9380]
# 		 sph: 0.7518 [0.7518]
# 		 tnt/ttr: 0.1455 [0.1455]
# 	 mean iou [soft]: 0.5199 [0.5199]
# 	 acc: 0.8652
#
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Pred shape: (256, 256)
# Mask resized shape: (256, 256)
# Pred one-hot shape: (256, 256, 7)
# Mask one-hot shape: (256, 256, 7)
# Metrics for test_07.jpg:
# 	 iou [soft]:
# 		 bg: 0.8581 [0.8581]
# 		 brt: 0.0005 [0.0005]
# 		 ccp/kub: 0.7075 [0.7075]
# 		 gl: 0.4593 [0.4593]
# 		 py/mrc: 0.9701 [0.9701]
# 		 sph: 0.7299 [0.7299]
# 		 tnt/ttr: 0.0129 [0.0129]
# 	 mean iou [soft]: 0.5340 [0.5340]
# 	 acc: 0.9285
#
# Metrics with void borders for test_07.jpg:
# 	 iou [soft]:
# 		 bg: 0.8581 [0.8581]
# 		 brt: 0.0005 [0.0005]
# 		 ccp/kub: 0.7075 [0.7075]
# 		 gl: 0.4593 [0.4593]
# 		 py/mrc: 0.9701 [0.9701]
# 		 sph: 0.7299 [0.7299]
# 		 tnt/ttr: 0.0129 [0.0129]
# 	 mean iou [soft]: 0.5340 [0.5340]
# 	 acc: 0.9285
#
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Pred shape: (256, 256)
# Mask resized shape: (256, 256)
# Pred one-hot shape: (256, 256, 7)
# Mask one-hot shape: (256, 256, 7)
# Metrics for test_08.jpg:
# 	 iou [soft]:
# 		 bg: 0.4576 [0.4576]
# 		 brt: 0.0000 [0.0000]
# 		 ccp/kub: 0.3232 [0.3232]
# 		 gl: 0.9171 [0.9171]
# 		 py/mrc: 0.9841 [0.9841]
# 		 sph: 0.7742 [0.7742]
# 		 tnt/ttr: 0.0002 [0.0002]
# 	 mean iou [soft]: 0.4938 [0.4938]
# 	 acc: 0.9075
#
# Metrics with void borders for test_08.jpg:
# 	 iou [soft]:
# 		 bg: 0.4576 [0.4576]
# 		 brt: 0.0000 [0.0000]
# 		 ccp/kub: 0.3232 [0.3232]
# 		 gl: 0.9171 [0.9171]
# 		 py/mrc: 0.9841 [0.9841]
# 		 sph: 0.7742 [0.7742]
# 		 tnt/ttr: 0.0002 [0.0002]
# 	 mean iou [soft]: 0.4938 [0.4938]
# 	 acc: 0.9075
#
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Pred shape: (256, 256)
# Mask resized shape: (256, 256)
# Pred one-hot shape: (256, 256, 7)
# Mask one-hot shape: (256, 256, 7)
# Metrics for test_09.jpg:
# 	 iou [soft]:
# 		 bg: 0.8984 [0.8984]
# 		 brt: 0.0002 [0.0002]
# 		 ccp/kub: 0.8500 [0.8500]
# 		 gl: 0.0026 [0.0026]
# 		 py/mrc: 0.9573 [0.9573]
# 		 sph: 0.7102 [0.7102]
# 		 tnt/ttr: 0.0170 [0.0170]
# 	 mean iou [soft]: 0.4908 [0.4908]
# 	 acc: 0.9244
#
# Metrics with void borders for test_09.jpg:
# 	 iou [soft]:
# 		 bg: 0.8984 [0.8984]
# 		 brt: 0.0002 [0.0002]
# 		 ccp/kub: 0.8500 [0.8500]
# 		 gl: 0.0026 [0.0026]
# 		 py/mrc: 0.9573 [0.9573]
# 		 sph: 0.7102 [0.7102]
# 		 tnt/ttr: 0.0170 [0.0170]
# 	 mean iou [soft]: 0.4908 [0.4908]
# 	 acc: 0.9244
#
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Pred shape: (256, 256)
# Mask resized shape: (256, 256)
# Pred one-hot shape: (256, 256, 7)
# Mask one-hot shape: (256, 256, 7)
# Metrics for test_10.jpg:
# 	 iou [soft]:
# 		 bg: 0.8235 [0.8235]
# 		 brt: 0.0000 [0.0000]
# 		 ccp/kub: 0.7551 [0.7551]
# 		 gl: 0.1335 [0.1335]
# 		 py/mrc: 0.9510 [0.9510]
# 		 sph: 0.7730 [0.7730]
# 		 tnt/ttr: 0.0033 [0.0033]
# 	 mean iou [soft]: 0.4914 [0.4914]
# 	 acc: 0.9051
#
# Metrics with void borders for test_10.jpg:
# 	 iou [soft]:
# 		 bg: 0.8235 [0.8235]
# 		 brt: 0.0000 [0.0000]
# 		 ccp/kub: 0.7551 [0.7551]
# 		 gl: 0.1335 [0.1335]
# 		 py/mrc: 0.9510 [0.9510]
# 		 sph: 0.7730 [0.7730]
# 		 tnt/ttr: 0.0033 [0.0033]
# 	 mean iou [soft]: 0.4914 [0.4914]
# 	 acc: 0.9051
#
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Pred shape: (256, 256)
# Mask resized shape: (256, 256)
# Pred one-hot shape: (256, 256, 7)
# Mask one-hot shape: (256, 256, 7)
# Metrics for test_11.jpg:
# 	 iou [soft]:
# 		 bg: 0.8650 [0.8650]
# 		 brt: 0.0002 [0.0002]
# 		 ccp/kub: 0.8127 [0.8127]
# 		 gl: 0.3336 [0.3336]
# 		 py/mrc: 0.9542 [0.9542]
# 		 sph: 0.7532 [0.7532]
# 		 tnt/ttr: 0.0931 [0.0931]
# 	 mean iou [soft]: 0.5446 [0.5446]
# 	 acc: 0.9159
#
# Metrics with void borders for test_11.jpg:
# 	 iou [soft]:
# 		 bg: 0.8650 [0.8650]
# 		 brt: 0.0002 [0.0002]
# 		 ccp/kub: 0.8127 [0.8127]
# 		 gl: 0.3336 [0.3336]
# 		 py/mrc: 0.9542 [0.9542]
# 		 sph: 0.7532 [0.7532]
# 		 tnt/ttr: 0.0931 [0.0931]
# 	 mean iou [soft]: 0.5446 [0.5446]
# 	 acc: 0.9159
#
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Pred shape: (256, 256)
# Mask resized shape: (256, 256)
# Pred one-hot shape: (256, 256, 7)
# Mask one-hot shape: (256, 256, 7)
# Metrics for test_12.jpg:
# 	 iou [soft]:
# 		 bg: 0.6918 [0.6918]
# 		 brt: 0.0005 [0.0005]
# 		 ccp/kub: 0.8082 [0.8082]
# 		 gl: 0.4874 [0.4874]
# 		 py/mrc: 0.9407 [0.9407]
# 		 sph: 0.7735 [0.7735]
# 		 tnt/ttr: 0.7572 [0.7572]
# 	 mean iou [soft]: 0.6370 [0.6370]
# 	 acc: 0.8898
#
# Metrics with void borders for test_12.jpg:
# 	 iou [soft]:
# 		 bg: 0.6918 [0.6918]
# 		 brt: 0.0005 [0.0005]
# 		 ccp/kub: 0.8082 [0.8082]
# 		 gl: 0.4874 [0.4874]
# 		 py/mrc: 0.9407 [0.9407]
# 		 sph: 0.7735 [0.7735]
# 		 tnt/ttr: 0.7572 [0.7572]
# 	 mean iou [soft]: 0.6370 [0.6370]
# 	 acc: 0.8898
#
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Pred shape: (256, 256)
# Mask resized shape: (256, 256)
# Pred one-hot shape: (256, 256, 7)
# Mask one-hot shape: (256, 256, 7)
# Metrics for test_13.jpg:
# 	 iou [soft]:
# 		 bg: 0.9699 [0.9699]
# 		 brt: 1.0000 [1.0000]
# 		 ccp/kub: 0.7297 [0.7297]
# 		 gl: 0.0000 [0.0000]
# 		 py/mrc: 0.6523 [0.6523]
# 		 sph: 0.9266 [0.9266]
# 		 tnt/ttr: 0.7863 [0.7863]
# 	 mean iou [soft]: 0.7236 [0.7236]
# 	 acc: 0.9472
#
# Metrics with void borders for test_13.jpg:
# 	 iou [soft]:
# 		 bg: 0.9699 [0.9699]
# 		 brt: 1.0000 [1.0000]
# 		 ccp/kub: 0.7297 [0.7297]
# 		 gl: 0.0000 [0.0000]
# 		 py/mrc: 0.6523 [0.6523]
# 		 sph: 0.9266 [0.9266]
# 		 tnt/ttr: 0.7863 [0.7863]
# 	 mean iou [soft]: 0.7236 [0.7236]
# 	 acc: 0.9472
#
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Pred shape: (256, 256)
# Mask resized shape: (256, 256)
# Pred one-hot shape: (256, 256, 7)
# Mask one-hot shape: (256, 256, 7)
# Metrics for test_14.jpg:
# 	 iou [soft]:
# 		 bg: 0.8840 [0.8840]
# 		 brt: 0.8230 [0.8230]
# 		 ccp/kub: 0.0000 [0.0000]
# 		 gl: 0.3353 [0.3353]
# 		 py/mrc: 0.9814 [0.9814]
# 		 sph: 0.8439 [0.8439]
# 		 tnt/ttr: 0.0000 [0.0000]
# 	 mean iou [soft]: 0.5525 [0.5525]
# 	 acc: 0.9549
#
# Metrics with void borders for test_14.jpg:
# 	 iou [soft]:
# 		 bg: 0.8840 [0.8840]
# 		 brt: 0.8230 [0.8230]
# 		 ccp/kub: 0.0000 [0.0000]
# 		 gl: 0.3353 [0.3353]
# 		 py/mrc: 0.9814 [0.9814]
# 		 sph: 0.8439 [0.8439]
# 		 tnt/ttr: 0.0000 [0.0000]
# 	 mean iou [soft]: 0.5525 [0.5525]
# 	 acc: 0.9549
#
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Pred shape: (256, 256)
# Mask resized shape: (256, 256)
# Pred one-hot shape: (256, 256, 7)
# Mask one-hot shape: (256, 256, 7)
# Metrics for test_15.jpg:
# 	 iou [soft]:
# 		 bg: 0.9453 [0.9453]
# 		 brt: 0.4794 [0.4794]
# 		 ccp/kub: 0.0000 [0.0000]
# 		 gl: 0.0002 [0.0002]
# 		 py/mrc: 0.9198 [0.9198]
# 		 sph: 0.3595 [0.3595]
# 		 tnt/ttr: 0.0000 [0.0000]
# 	 mean iou [soft]: 0.3863 [0.3863]
# 	 acc: 0.8862
#
# Metrics with void borders for test_15.jpg:
# 	 iou [soft]:
# 		 bg: 0.9453 [0.9453]
# 		 brt: 0.4794 [0.4794]
# 		 ccp/kub: 0.0000 [0.0000]
# 		 gl: 0.0002 [0.0002]
# 		 py/mrc: 0.9198 [0.9198]
# 		 sph: 0.3595 [0.3595]
# 		 tnt/ttr: 0.0000 [0.0000]
# 	 mean iou [soft]: 0.3863 [0.3863]
# 	 acc: 0.8862
#
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Pred shape: (256, 256)
# Mask resized shape: (256, 256)
# Pred one-hot shape: (256, 256, 7)
# Mask one-hot shape: (256, 256, 7)
# Metrics for test_16.jpg:
# 	 iou [soft]:
# 		 bg: 0.9051 [0.9051]
# 		 brt: 0.5289 [0.5289]
# 		 ccp/kub: 0.4435 [0.4435]
# 		 gl: 0.0003 [0.0003]
# 		 py/mrc: 0.0000 [0.0000]
# 		 sph: 0.7854 [0.7854]
# 		 tnt/ttr: 0.0000 [0.0000]
# 	 mean iou [soft]: 0.3805 [0.3805]
# 	 acc: 0.7815
#
# Metrics with void borders for test_16.jpg:
# 	 iou [soft]:
# 		 bg: 0.9051 [0.9051]
# 		 brt: 0.5289 [0.5289]
# 		 ccp/kub: 0.4435 [0.4435]
# 		 gl: 0.0003 [0.0003]
# 		 py/mrc: 0.0000 [0.0000]
# 		 sph: 0.7854 [0.7854]
# 		 tnt/ttr: 0.0000 [0.0000]
# 	 mean iou [soft]: 0.3805 [0.3805]
# 	 acc: 0.7815
#
# --------------------------------------------------
