# %% [markdown]
# Подключение google disk для использования dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Установка библиотеки

# %%
# !pip install petroscope
# Out:
# Requirement already satisfied: petroscope in /usr/local/lib/python3.11/dist-packages (0.0.11)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from petroscope) (6.0.2)
# Requirement already satisfied: numpy<2.0.0,>=1.16 in /usr/local/lib/python3.11/dist-packages (from petroscope) (1.26.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from petroscope) (11.1.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from petroscope) (3.10.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from petroscope) (4.67.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from petroscope) (1.15.2)
# Requirement already satisfied: loguru in /usr/local/lib/python3.11/dist-packages (from petroscope) (0.7.3)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.11/dist-packages (from petroscope) (3.15.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from petroscope) (2.32.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->petroscope) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->petroscope) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->petroscope) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->petroscope) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->petroscope) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->petroscope) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->petroscope) (2.8.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prettytable->petroscope) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->petroscope) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->petroscope) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->petroscope) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->petroscope) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->petroscope) (1.17.0)

# %% [markdown]
# Импорт неободимых библиотек

# %%
from pathlib import Path
from petroscope.segmentation.classes import ClassSet, LumenStoneClasses
from petroscope.segmentation.utils import load_image, load_mask
from petroscope.segmentation import GeoSegmModel
import numpy as np
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from skimage.color import rgb2lab

# %% [markdown]
# Путь к dataset

# %%
ds_path = Path('/content/drive/MyDrive/PhotoSets/')

# %% [markdown]
# Инциализация набора классов для сегментации

# %%
classset = LumenStoneClasses.S1v1()

for cl in classset.classes:
    print(cl)
# Out:
# [0, bg (background), color: #000000]
# [1, ccp/kub (chalcopyrite/cubanite), color: #ffa500]
# [2, gl (galena), color: #9acd32]
# [4, brt (bornite), color: #00bfff]
# [6, py/mrc (pyrite/marcasite), color: #2f4f4f]
# [8, sph (sphalerite), color: #ee82ee]
# [11, tnt/ttr (tenantite/tetrahedrite), color: #483d8b]

# %% [markdown]
# Формирование путей к изображениям и маскам

# %%
train_img_mask_p = [
    (img_p, ds_path / "masks" / "train" / f"{img_p.stem}.png")
    for img_p in sorted((ds_path / "imgs" / "train").iterdir())
]

test_img_mask_p = [
    (img_p, ds_path / "masks" / "test" / f"{img_p.stem}.png")
    for img_p in sorted((ds_path / "imgs" / "test").iterdir())
]

# %% [markdown]
# Загрузка и конвертация обучающих изображений в пространство LAB

# %%
for img_p, _ in train_img_mask_p:
    img = load_image(img_p, normalize=True)
    img_lab = rgb2lab(img)
    print(f"Image {img_p.name}: {img_lab.shape}, {img_lab.dtype}")
# Out:
# Image train_01.jpg: (2547, 3396, 3), float32
# Image train_02.jpg: (2547, 3396, 3), float32
# Image train_03.jpg: (2547, 3396, 3), float32
# Image train_04.jpg: (2547, 3396, 3), float32
# Image train_06.jpg: (2547, 3396, 3), float32
# Image train_07.jpg: (2547, 3396, 3), float32
# Image train_08.jpg: (2547, 3396, 3), float32
# Image train_09.jpg: (2547, 3396, 3), float32
# Image train_10.jpg: (2547, 3396, 3), float32
# Image train_11.jpg: (2547, 3396, 3), float32
# Image train_12.jpg: (2547, 3396, 3), float32
# Image train_13.jpg: (2547, 3396, 3), float32
# Image train_14.jpg: (2547, 3396, 3), float32
# Image train_15.jpg: (2547, 3396, 3), float32
# Image train_16.jpg: (2547, 3396, 3), float32
# Image train_17.jpg: (2547, 3396, 3), float32
# Image train_18.jpg: (2547, 3396, 3), float32
# Image train_19.jpg: (2547, 3396, 3), float32
# Image train_20.jpg: (2547, 3396, 3), float32
# Image train_21.jpg: (2547, 3396, 3), float32
# Image train_22.jpg: (2547, 3396, 3), float32
# Image train_23.jpg: (2547, 3396, 3), float32
# Image train_24.jpg: (2547, 3396, 3), float32
# Image train_25.jpg: (2547, 3396, 3), float32
# Image train_26.jpg: (2547, 3396, 3), float32
# Image train_27.jpg: (2547, 3396, 3), float32
# Image train_28.jpg: (2547, 3396, 3), float32
# Image train_29.jpg: (2547, 3396, 3), float32
# Image train_30.jpg: (2547, 3396, 3), float32
# Image train_31.jpg: (2547, 3396, 3), float32
# Image train_32.jpg: (2547, 3396, 3), float32
# Image train_33.jpg: (2547, 3396, 3), float32
# Image train_34.jpg: (2547, 3396, 3), float32
# Image train_35.jpg: (2547, 3396, 3), float32
# Image train_36.jpg: (2547, 3396, 3), float32
# Image train_37.jpg: (2547, 3396, 3), float32
# Image train_38.jpg: (2547, 3396, 3), float32
# Image train_39.jpg: (2547, 3396, 3), float32
# Image train_40.jpg: (2547, 3396, 3), float32
# Image train_41.jpg: (2547, 3396, 3), float32
# Image train_42.jpg: (2547, 3396, 3), float32
# Image train_43.jpg: (2547, 3396, 3), float32
# Image train_44.jpg: (2547, 3396, 3), float32
# Image train_45.jpg: (2547, 3396, 3), float32
# Image train_46.jpg: (2547, 3396, 3), float32
# Image train_47.jpg: (2547, 3396, 3), float32
# Image train_48.jpg: (2547, 3396, 3), float32
# Image train_49.jpg: (2547, 3396, 3), float32
# Image train_50.jpg: (2547, 3396, 3), float32
# Image train_51.jpg: (2547, 3396, 3), float32
# Image train_52.jpg: (2547, 3396, 3), float32
# Image train_53.jpg: (2547, 3396, 3), float32
# Image train_54.jpg: (2547, 3396, 3), float32
# Image train_55.jpg: (2547, 3396, 3), float32
# Image train_56.jpg: (2547, 3396, 3), float32
# Image train_57.jpg: (2547, 3396, 3), float32
# Image train_58.jpg: (2547, 3396, 3), float32
# Image train_59.jpg: (2547, 3396, 3), float32

# %% [markdown]
# Загрузка масок без one-hot кодирования

# %%
for _, mask_p in train_img_mask_p:
    mask = load_mask(mask_p, classes=classset, one_hot=False)
    print(f"Mask {mask_p.name}: {mask.shape}, {mask.dtype}")
# Out:
# Mask train_01.png: (2547, 3396), uint8
# Mask train_02.png: (2547, 3396), uint8
# Mask train_03.png: (2547, 3396), uint8
# Mask train_04.png: (2547, 3396), uint8
# Mask train_06.png: (2547, 3396), uint8
# Mask train_07.png: (2547, 3396), uint8
# Mask train_08.png: (2547, 3396), uint8
# Mask train_09.png: (2547, 3396), uint8
# Mask train_10.png: (2547, 3396), uint8
# Mask train_11.png: (2547, 3396), uint8
# Mask train_12.png: (2547, 3396), uint8
# Mask train_13.png: (2547, 3396), uint8
# Mask train_14.png: (2547, 3396), uint8
# Mask train_15.png: (2547, 3396), uint8
# Mask train_16.png: (2547, 3396), uint8
# Mask train_17.png: (2547, 3396), uint8
# Mask train_18.png: (2547, 3396), uint8
# Mask train_19.png: (2547, 3396), uint8
# Mask train_20.png: (2547, 3396), uint8
# Mask train_21.png: (2547, 3396), uint8
# Mask train_22.png: (2547, 3396), uint8
# Mask train_23.png: (2547, 3396), uint8
# Mask train_24.png: (2547, 3396), uint8
# Mask train_25.png: (2547, 3396), uint8
# Mask train_26.png: (2547, 3396), uint8
# Mask train_27.png: (2547, 3396), uint8
# Mask train_28.png: (2547, 3396), uint8
# Mask train_29.png: (2547, 3396), uint8
# Mask train_30.png: (2547, 3396), uint8
# Mask train_31.png: (2547, 3396), uint8
# Mask train_32.png: (2547, 3396), uint8
# Mask train_33.png: (2547, 3396), uint8
# Mask train_34.png: (2547, 3396), uint8
# Mask train_35.png: (2547, 3396), uint8
# Mask train_36.png: (2547, 3396), uint8
# Mask train_37.png: (2547, 3396), uint8
# Mask train_38.png: (2547, 3396), uint8
# Mask train_39.png: (2547, 3396), uint8
# Mask train_40.png: (2547, 3396), uint8
# Mask train_41.png: (2547, 3396), uint8
# Mask train_42.png: (2547, 3396), uint8
# Mask train_43.png: (2547, 3396), uint8
# Mask train_44.png: (2547, 3396), uint8
# Mask train_45.png: (2547, 3396), uint8
# Mask train_46.png: (2547, 3396), uint8
# Mask train_47.png: (2547, 3396), uint8
# Mask train_48.png: (2547, 3396), uint8
# Mask train_49.png: (2547, 3396), uint8
# Mask train_50.png: (2547, 3396), uint8
# Mask train_51.png: (2547, 3396), uint8
# Mask train_52.png: (2547, 3396), uint8
# Mask train_53.png: (2547, 3396), uint8
# Mask train_54.png: (2547, 3396), uint8
# Mask train_55.png: (2547, 3396), uint8
# Mask train_56.png: (2547, 3396), uint8
# Mask train_57.png: (2547, 3396), uint8
# Mask train_58.png: (2547, 3396), uint8
# Mask train_59.png: (2547, 3396), uint8

# %% [markdown]
# Загрузка масок с one-hot кодированием

# %%
for _, mask_p in train_img_mask_p:
    mask_one_hot = load_mask(mask_p, classes=classset, one_hot=True)
    print(f"Mask one-hot {mask_p.name}: {mask_one_hot.shape}, {mask_one_hot.dtype}")
# Out:
# Mask one-hot train_01.png: (2547, 3396, 7), float32
# Mask one-hot train_02.png: (2547, 3396, 7), float32
# Mask one-hot train_03.png: (2547, 3396, 7), float32
# Mask one-hot train_04.png: (2547, 3396, 7), float32
# Mask one-hot train_06.png: (2547, 3396, 7), float32
# Mask one-hot train_07.png: (2547, 3396, 7), float32
# Mask one-hot train_08.png: (2547, 3396, 7), float32
# Mask one-hot train_09.png: (2547, 3396, 7), float32
# Mask one-hot train_10.png: (2547, 3396, 7), float32
# Mask one-hot train_11.png: (2547, 3396, 7), float32
# Mask one-hot train_12.png: (2547, 3396, 7), float32
# Mask one-hot train_13.png: (2547, 3396, 7), float32
# Mask one-hot train_14.png: (2547, 3396, 7), float32
# Mask one-hot train_15.png: (2547, 3396, 7), float32
# Mask one-hot train_16.png: (2547, 3396, 7), float32
# Mask one-hot train_17.png: (2547, 3396, 7), float32
# Mask one-hot train_18.png: (2547, 3396, 7), float32
# Mask one-hot train_19.png: (2547, 3396, 7), float32
# Mask one-hot train_20.png: (2547, 3396, 7), float32
# Mask one-hot train_21.png: (2547, 3396, 7), float32
# Mask one-hot train_22.png: (2547, 3396, 7), float32
# Mask one-hot train_23.png: (2547, 3396, 7), float32
# Mask one-hot train_24.png: (2547, 3396, 7), float32
# Mask one-hot train_25.png: (2547, 3396, 7), float32
# Mask one-hot train_26.png: (2547, 3396, 7), float32
# Mask one-hot train_27.png: (2547, 3396, 7), float32
# Mask one-hot train_28.png: (2547, 3396, 7), float32
# Mask one-hot train_29.png: (2547, 3396, 7), float32
# Mask one-hot train_30.png: (2547, 3396, 7), float32
# Mask one-hot train_31.png: (2547, 3396, 7), float32
# Mask one-hot train_32.png: (2547, 3396, 7), float32
# Mask one-hot train_33.png: (2547, 3396, 7), float32
# Mask one-hot train_34.png: (2547, 3396, 7), float32
# Mask one-hot train_35.png: (2547, 3396, 7), float32
# Mask one-hot train_36.png: (2547, 3396, 7), float32
# Mask one-hot train_37.png: (2547, 3396, 7), float32
# Mask one-hot train_38.png: (2547, 3396, 7), float32
# Mask one-hot train_39.png: (2547, 3396, 7), float32
# Mask one-hot train_40.png: (2547, 3396, 7), float32
# Mask one-hot train_41.png: (2547, 3396, 7), float32
# Mask one-hot train_42.png: (2547, 3396, 7), float32
# Mask one-hot train_43.png: (2547, 3396, 7), float32
# Mask one-hot train_44.png: (2547, 3396, 7), float32
# Mask one-hot train_45.png: (2547, 3396, 7), float32
# Mask one-hot train_46.png: (2547, 3396, 7), float32
# Mask one-hot train_47.png: (2547, 3396, 7), float32
# Mask one-hot train_48.png: (2547, 3396, 7), float32
# Mask one-hot train_49.png: (2547, 3396, 7), float32
# Mask one-hot train_50.png: (2547, 3396, 7), float32
# Mask one-hot train_51.png: (2547, 3396, 7), float32
# Mask one-hot train_52.png: (2547, 3396, 7), float32
# Mask one-hot train_53.png: (2547, 3396, 7), float32
# Mask one-hot train_54.png: (2547, 3396, 7), float32
# Mask one-hot train_55.png: (2547, 3396, 7), float32
# Mask one-hot train_56.png: (2547, 3396, 7), float32
# Mask one-hot train_57.png: (2547, 3396, 7), float32
# Mask one-hot train_58.png: (2547, 3396, 7), float32
# Mask one-hot train_59.png: (2547, 3396, 7), float32

# %% [markdown]
# Загрузка цветных масок

# %%
for img_p, _ in train_img_mask_p:
    mask_colored_path = ds_path / "masks_colored_png" / "train" / f"{img_p.stem}.png"
    mask_colored = load_image(mask_colored_path, normalize=False)
    print(f"Colored mask {mask_colored_path.name}: {mask_colored.shape}, {mask_colored.dtype}")
# Out:
# Colored mask train_01.png: (2547, 3396, 3), uint8
# Colored mask train_02.png: (2547, 3396, 3), uint8
# Colored mask train_03.png: (2547, 3396, 3), uint8
# Colored mask train_04.png: (2547, 3396, 3), uint8
# Colored mask train_06.png: (2547, 3396, 3), uint8
# Colored mask train_07.png: (2547, 3396, 3), uint8
# Colored mask train_08.png: (2547, 3396, 3), uint8
# Colored mask train_09.png: (2547, 3396, 3), uint8
# Colored mask train_10.png: (2547, 3396, 3), uint8
# Colored mask train_11.png: (2547, 3396, 3), uint8
# Colored mask train_12.png: (2547, 3396, 3), uint8
# Colored mask train_13.png: (2547, 3396, 3), uint8
# Colored mask train_14.png: (2547, 3396, 3), uint8
# Colored mask train_15.png: (2547, 3396, 3), uint8
# Colored mask train_16.png: (2547, 3396, 3), uint8
# Colored mask train_17.png: (2547, 3396, 3), uint8
# Colored mask train_18.png: (2547, 3396, 3), uint8
# Colored mask train_19.png: (2547, 3396, 3), uint8
# Colored mask train_20.png: (2547, 3396, 3), uint8
# Colored mask train_21.png: (2547, 3396, 3), uint8
# Colored mask train_22.png: (2547, 3396, 3), uint8
# Colored mask train_23.png: (2547, 3396, 3), uint8
# Colored mask train_24.png: (2547, 3396, 3), uint8
# Colored mask train_25.png: (2547, 3396, 3), uint8
# Colored mask train_26.png: (2547, 3396, 3), uint8
# Colored mask train_27.png: (2547, 3396, 3), uint8
# Colored mask train_28.png: (2547, 3396, 3), uint8
# Colored mask train_29.png: (2547, 3396, 3), uint8
# Colored mask train_30.png: (2547, 3396, 3), uint8
# Colored mask train_31.png: (2547, 3396, 3), uint8
# Colored mask train_32.png: (2547, 3396, 3), uint8
# Colored mask train_33.png: (2547, 3396, 3), uint8
# Colored mask train_34.png: (2547, 3396, 3), uint8
# Colored mask train_35.png: (2547, 3396, 3), uint8
# Colored mask train_36.png: (2547, 3396, 3), uint8
# Colored mask train_37.png: (2547, 3396, 3), uint8
# Colored mask train_38.png: (2547, 3396, 3), uint8
# Colored mask train_39.png: (2547, 3396, 3), uint8
# Colored mask train_40.png: (2547, 3396, 3), uint8
# Colored mask train_41.png: (2547, 3396, 3), uint8
# Colored mask train_42.png: (2547, 3396, 3), uint8
# Colored mask train_43.png: (2547, 3396, 3), uint8
# Colored mask train_44.png: (2547, 3396, 3), uint8
# Colored mask train_45.png: (2547, 3396, 3), uint8
# Colored mask train_46.png: (2547, 3396, 3), uint8
# Colored mask train_47.png: (2547, 3396, 3), uint8
# Colored mask train_48.png: (2547, 3396, 3), uint8
# Colored mask train_49.png: (2547, 3396, 3), uint8
# Colored mask train_50.png: (2547, 3396, 3), uint8
# Colored mask train_51.png: (2547, 3396, 3), uint8
# Colored mask train_52.png: (2547, 3396, 3), uint8
# Colored mask train_53.png: (2547, 3396, 3), uint8
# Colored mask train_54.png: (2547, 3396, 3), uint8
# Colored mask train_55.png: (2547, 3396, 3), uint8
# Colored mask train_56.png: (2547, 3396, 3), uint8
# Colored mask train_57.png: (2547, 3396, 3), uint8
# Colored mask train_58.png: (2547, 3396, 3), uint8
# Colored mask train_59.png: (2547, 3396, 3), uint8

# %% [markdown]
# Функция для загрузки и предобработки изображений и масок

# %%
def load_and_preprocess(img_path, mask_path, classes, img_size=(256, 256)):
    img = load_image(img_path, normalize=True)
    img = tf.image.resize(img, img_size)

    mask = load_mask(mask_path, classes=classes, one_hot=False)
    mask = tf.image.resize(mask[..., np.newaxis], img_size, method='nearest')
    mask = to_categorical(mask, num_classes=len(classes))

    return img, mask

# %% [markdown]
# Модель U-Net

# %%
def unet_model(input_size=(256, 256, 3), num_classes=7):
    inputs = Input(input_size)

    conv1 = Conv2D(64, 3, activation='relu', padding='same')(inputs)
    conv1 = Conv2D(64, 3, activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(128, 3, activation='relu', padding='same')(pool1)
    conv2 = Conv2D(128, 3, activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation='relu', padding='same')(pool2)
    conv3 = Conv2D(256, 3, activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(512, 3, activation='relu', padding='same')(pool3)
    conv4 = Conv2D(512, 3, activation='relu', padding='same')(conv4)

    up5 = concatenate([UpSampling2D(size=(2, 2))(conv4), conv3], axis=-1)
    conv5 = Conv2D(256, 3, activation='relu', padding='same')(up5)
    conv5 = Conv2D(256, 3, activation='relu', padding='same')(conv5)
    up6 = concatenate([UpSampling2D(size=(2, 2))(conv5), conv2], axis=-1)
    conv6 = Conv2D(128, 3, activation='relu', padding='same')(up6)
    conv6 = Conv2D(128, 3, activation='relu', padding='same')(conv6)
    up7 = concatenate([UpSampling2D(size=(2, 2))(conv6), conv1], axis=-1)
    conv7 = Conv2D(64, 3, activation='relu', padding='same')(up7)
    conv7 = Conv2D(64, 3, activation='relu', padding='same')(conv7)

    outputs = Conv2D(num_classes, 1, activation='softmax')(conv7)

    model = Model(inputs=[inputs], outputs=[outputs])
    model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %% [markdown]
# Загрузка и предобработка обучающих данных

# %%
train_data = [load_and_preprocess(img_p, mask_p, classset) for img_p, mask_p in train_img_mask_p]
train_images, train_masks = zip(*train_data)
train_images = np.array(train_images)
train_masks = np.array(train_masks)

print(f"Train images shape: {train_images.shape}")
print(f"Train masks shape: {train_masks.shape}")

model = unet_model(num_classes=len(classset.classes))

model.fit([train_images], [train_masks], batch_size=4, epochs=200, validation_split=0.1)
# Out:
# Train images shape: (58, 256, 256, 3)
# Train masks shape: (58, 256, 256, 7)
# Epoch 1/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - accuracy: 0.2604 - loss: 2.7425 - val_accuracy: 0.0320 - val_loss: 2.8744
# Epoch 2/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 41s 193ms/step - accuracy: 0.3397 - loss: 1.5977 - val_accuracy: 0.3421 - val_loss: 2.1169
# Epoch 3/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 201ms/step - accuracy: 0.3767 - loss: 1.4430 - val_accuracy: 0.4005 - val_loss: 2.4244
# Epoch 4/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 198ms/step - accuracy: 0.5162 - loss: 1.2350 - val_accuracy: 0.4877 - val_loss: 1.9759
# Epoch 5/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 194ms/step - accuracy: 0.6480 - loss: 1.0721 - val_accuracy: 0.4814 - val_loss: 2.2953
# Epoch 6/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 201ms/step - accuracy: 0.7185 - loss: 0.9932 - val_accuracy: 0.4951 - val_loss: 2.1782
# Epoch 7/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 200ms/step - accuracy: 0.7175 - loss: 0.9665 - val_accuracy: 0.4947 - val_loss: 2.3204
# Epoch 8/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 199ms/step - accuracy: 0.7370 - loss: 0.8615 - val_accuracy: 0.4166 - val_loss: 2.0484
# Epoch 9/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 199ms/step - accuracy: 0.6645 - loss: 0.9767 - val_accuracy: 0.5063 - val_loss: 1.8918
# Epoch 10/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 204ms/step - accuracy: 0.7444 - loss: 0.8176 - val_accuracy: 0.5166 - val_loss: 2.0617
# Epoch 11/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 204ms/step - accuracy: 0.7853 - loss: 0.7220 - val_accuracy: 0.4335 - val_loss: 2.1036
# Epoch 12/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 209ms/step - accuracy: 0.7929 - loss: 0.6978 - val_accuracy: 0.4876 - val_loss: 2.1281
# Epoch 13/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 210ms/step - accuracy: 0.8017 - loss: 0.6388 - val_accuracy: 0.4822 - val_loss: 1.9882
# Epoch 14/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 209ms/step - accuracy: 0.8103 - loss: 0.6464 - val_accuracy: 0.4757 - val_loss: 1.9136
# Epoch 15/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 207ms/step - accuracy: 0.7668 - loss: 0.7366 - val_accuracy: 0.5009 - val_loss: 2.2652
# Epoch 16/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - accuracy: 0.7757 - loss: 0.7436 - val_accuracy: 0.4626 - val_loss: 1.7603
# Epoch 17/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 204ms/step - accuracy: 0.7470 - loss: 0.7595 - val_accuracy: 0.4977 - val_loss: 2.5076
# Epoch 18/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 201ms/step - accuracy: 0.7698 - loss: 0.7521 - val_accuracy: 0.4986 - val_loss: 1.9039
# Epoch 19/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 204ms/step - accuracy: 0.8081 - loss: 0.6395 - val_accuracy: 0.5078 - val_loss: 1.7067
# Epoch 20/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 201ms/step - accuracy: 0.8073 - loss: 0.6289 - val_accuracy: 0.4637 - val_loss: 1.7055
# Epoch 21/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 203ms/step - accuracy: 0.7321 - loss: 0.8244 - val_accuracy: 0.5232 - val_loss: 1.7993
# Epoch 22/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 0.8266 - loss: 0.6130 - val_accuracy: 0.5223 - val_loss: 1.6574
# Epoch 23/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 203ms/step - accuracy: 0.8053 - loss: 0.6213 - val_accuracy: 0.5238 - val_loss: 1.6523
# Epoch 24/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 200ms/step - accuracy: 0.7949 - loss: 0.6361 - val_accuracy: 0.5245 - val_loss: 1.5140
# Epoch 25/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 200ms/step - accuracy: 0.8014 - loss: 0.6387 - val_accuracy: 0.4993 - val_loss: 1.4901
# Epoch 26/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 203ms/step - accuracy: 0.7743 - loss: 0.6786 - val_accuracy: 0.5195 - val_loss: 1.9210
# Epoch 27/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 198ms/step - accuracy: 0.8049 - loss: 0.6092 - val_accuracy: 0.4957 - val_loss: 1.6779
# Epoch 28/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 198ms/step - accuracy: 0.8270 - loss: 0.5513 - val_accuracy: 0.4646 - val_loss: 1.6571
# Epoch 29/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 199ms/step - accuracy: 0.7947 - loss: 0.6481 - val_accuracy: 0.5255 - val_loss: 1.4714
# Epoch 30/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 198ms/step - accuracy: 0.8052 - loss: 0.5963 - val_accuracy: 0.5246 - val_loss: 1.5141
# Epoch 31/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 200ms/step - accuracy: 0.7641 - loss: 0.7427 - val_accuracy: 0.5255 - val_loss: 1.6542
# Epoch 32/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 0.8194 - loss: 0.5694 - val_accuracy: 0.5255 - val_loss: 1.4686
# Epoch 33/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 201ms/step - accuracy: 0.8297 - loss: 0.5039 - val_accuracy: 0.5242 - val_loss: 1.5416
# Epoch 34/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 201ms/step - accuracy: 0.8036 - loss: 0.5538 - val_accuracy: 0.4853 - val_loss: 1.5796
# Epoch 35/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - accuracy: 0.8141 - loss: 0.5620 - val_accuracy: 0.5240 - val_loss: 1.6534
# Epoch 36/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 204ms/step - accuracy: 0.7864 - loss: 0.6319 - val_accuracy: 0.5141 - val_loss: 1.3434
# Epoch 37/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 0.8530 - loss: 0.4416 - val_accuracy: 0.4986 - val_loss: 1.5236
# Epoch 38/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - accuracy: 0.8140 - loss: 0.5360 - val_accuracy: 0.5086 - val_loss: 1.6836
# Epoch 39/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 203ms/step - accuracy: 0.8019 - loss: 0.5998 - val_accuracy: 0.4810 - val_loss: 1.1695
# Epoch 40/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 0.7597 - loss: 0.6821 - val_accuracy: 0.5202 - val_loss: 1.1197
# Epoch 41/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 206ms/step - accuracy: 0.8315 - loss: 0.4722 - val_accuracy: 0.4609 - val_loss: 1.6012
# Epoch 42/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - accuracy: 0.8257 - loss: 0.5251 - val_accuracy: 0.4999 - val_loss: 1.2491
# Epoch 43/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 200ms/step - accuracy: 0.8369 - loss: 0.4990 - val_accuracy: 0.5324 - val_loss: 1.2107
# Epoch 44/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 204ms/step - accuracy: 0.8269 - loss: 0.5578 - val_accuracy: 0.6388 - val_loss: 0.9765
# Epoch 45/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 207ms/step - accuracy: 0.7640 - loss: 0.6551 - val_accuracy: 0.5580 - val_loss: 1.9465
# Epoch 46/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 199ms/step - accuracy: 0.8481 - loss: 0.5259 - val_accuracy: 0.5220 - val_loss: 1.5200
# Epoch 47/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 198ms/step - accuracy: 0.8200 - loss: 0.5771 - val_accuracy: 0.4834 - val_loss: 1.5148
# Epoch 48/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 204ms/step - accuracy: 0.8232 - loss: 0.5456 - val_accuracy: 0.5479 - val_loss: 1.1589
# Epoch 49/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 204ms/step - accuracy: 0.8410 - loss: 0.4780 - val_accuracy: 0.5283 - val_loss: 1.2687
# Epoch 50/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 205ms/step - accuracy: 0.8425 - loss: 0.4840 - val_accuracy: 0.5312 - val_loss: 1.4733
# Epoch 51/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - accuracy: 0.8428 - loss: 0.4804 - val_accuracy: 0.5450 - val_loss: 1.3415
# Epoch 52/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 203ms/step - accuracy: 0.8348 - loss: 0.5317 - val_accuracy: 0.5414 - val_loss: 1.2044
# Epoch 53/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 200ms/step - accuracy: 0.8195 - loss: 0.5130 - val_accuracy: 0.5301 - val_loss: 1.0664
# Epoch 54/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - accuracy: 0.8351 - loss: 0.4455 - val_accuracy: 0.5259 - val_loss: 1.4496
# Epoch 55/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 201ms/step - accuracy: 0.8434 - loss: 0.4828 - val_accuracy: 0.5160 - val_loss: 1.0807
# Epoch 56/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 201ms/step - accuracy: 0.8325 - loss: 0.4886 - val_accuracy: 0.5694 - val_loss: 0.8701
# Epoch 57/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 209ms/step - accuracy: 0.8666 - loss: 0.4194 - val_accuracy: 0.5433 - val_loss: 1.1758
# Epoch 58/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 204ms/step - accuracy: 0.8671 - loss: 0.3833 - val_accuracy: 0.5334 - val_loss: 1.0493
# Epoch 59/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 202ms/step - accuracy: 0.8518 - loss: 0.4673 - val_accuracy: 0.5807 - val_loss: 0.9558
# Epoch 60/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 0.8769 - loss: 0.3628 - val_accuracy: 0.4659 - val_loss: 1.4167
# Epoch 61/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 202ms/step - accuracy: 0.8385 - loss: 0.4626 - val_accuracy: 0.5317 - val_loss: 1.3693
# Epoch 62/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 206ms/step - accuracy: 0.8490 - loss: 0.4610 - val_accuracy: 0.5671 - val_loss: 0.9136
# Epoch 63/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 202ms/step - accuracy: 0.8391 - loss: 0.4620 - val_accuracy: 0.5335 - val_loss: 1.0075
# Epoch 64/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 200ms/step - accuracy: 0.7987 - loss: 0.5249 - val_accuracy: 0.5473 - val_loss: 1.2717
# Epoch 65/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 199ms/step - accuracy: 0.8632 - loss: 0.3993 - val_accuracy: 0.5443 - val_loss: 1.5671
# Epoch 66/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 206ms/step - accuracy: 0.8622 - loss: 0.4585 - val_accuracy: 0.5409 - val_loss: 1.1103
# Epoch 67/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 208ms/step - accuracy: 0.7970 - loss: 0.6794 - val_accuracy: 0.5446 - val_loss: 1.0250
# Epoch 68/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 201ms/step - accuracy: 0.8045 - loss: 0.5851 - val_accuracy: 0.5199 - val_loss: 0.9754
# Epoch 69/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - accuracy: 0.8392 - loss: 0.4764 - val_accuracy: 0.5350 - val_loss: 0.8681
# Epoch 70/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 200ms/step - accuracy: 0.8480 - loss: 0.4704 - val_accuracy: 0.5630 - val_loss: 1.6247
# Epoch 71/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 199ms/step - accuracy: 0.8365 - loss: 0.5099 - val_accuracy: 0.5344 - val_loss: 0.9972
# Epoch 72/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 206ms/step - accuracy: 0.8625 - loss: 0.4296 - val_accuracy: 0.5362 - val_loss: 0.9341
# Epoch 73/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 207ms/step - accuracy: 0.8770 - loss: 0.3736 - val_accuracy: 0.5522 - val_loss: 1.0079
# Epoch 74/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 203ms/step - accuracy: 0.8706 - loss: 0.3750 - val_accuracy: 0.4847 - val_loss: 1.8435
# Epoch 75/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 0.8379 - loss: 0.5348 - val_accuracy: 0.5243 - val_loss: 1.0733
# Epoch 76/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 0.8683 - loss: 0.3991 - val_accuracy: 0.5352 - val_loss: 0.9481
# Epoch 77/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 208ms/step - accuracy: 0.8599 - loss: 0.4014 - val_accuracy: 0.5589 - val_loss: 0.8445
# Epoch 78/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 204ms/step - accuracy: 0.8484 - loss: 0.4353 - val_accuracy: 0.5412 - val_loss: 1.1158
# Epoch 79/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 203ms/step - accuracy: 0.8535 - loss: 0.4479 - val_accuracy: 0.5605 - val_loss: 0.9973
# Epoch 80/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 200ms/step - accuracy: 0.8628 - loss: 0.3731 - val_accuracy: 0.5737 - val_loss: 0.9111
# Epoch 81/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 206ms/step - accuracy: 0.8643 - loss: 0.4403 - val_accuracy: 0.5712 - val_loss: 0.9412
# Epoch 82/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 200ms/step - accuracy: 0.8425 - loss: 0.4765 - val_accuracy: 0.5817 - val_loss: 0.8789
# Epoch 83/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 204ms/step - accuracy: 0.8526 - loss: 0.3944 - val_accuracy: 0.5477 - val_loss: 1.2299
# Epoch 84/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 201ms/step - accuracy: 0.7792 - loss: 0.5840 - val_accuracy: 0.5721 - val_loss: 0.9519
# Epoch 85/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 209ms/step - accuracy: 0.8827 - loss: 0.3551 - val_accuracy: 0.6029 - val_loss: 0.8124
# Epoch 86/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 199ms/step - accuracy: 0.8841 - loss: 0.3452 - val_accuracy: 0.6176 - val_loss: 0.7692
# Epoch 87/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 199ms/step - accuracy: 0.8504 - loss: 0.4916 - val_accuracy: 0.5200 - val_loss: 1.2723
# Epoch 88/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - accuracy: 0.8840 - loss: 0.3770 - val_accuracy: 0.5893 - val_loss: 0.9145
# Epoch 89/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 199ms/step - accuracy: 0.8660 - loss: 0.3970 - val_accuracy: 0.6238 - val_loss: 0.8277
# Epoch 90/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 199ms/step - accuracy: 0.9056 - loss: 0.2882 - val_accuracy: 0.5792 - val_loss: 0.9606
# Epoch 91/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 202ms/step - accuracy: 0.9026 - loss: 0.2987 - val_accuracy: 0.5334 - val_loss: 1.8107
# Epoch 92/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 206ms/step - accuracy: 0.8414 - loss: 0.5376 - val_accuracy: 0.5333 - val_loss: 1.4608
# Epoch 93/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 201ms/step - accuracy: 0.8683 - loss: 0.4067 - val_accuracy: 0.5116 - val_loss: 1.0634
# Epoch 94/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 202ms/step - accuracy: 0.8566 - loss: 0.4389 - val_accuracy: 0.5798 - val_loss: 0.8116
# Epoch 95/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 209ms/step - accuracy: 0.8820 - loss: 0.3607 - val_accuracy: 0.5871 - val_loss: 0.9615
# Epoch 96/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 206ms/step - accuracy: 0.8711 - loss: 0.3799 - val_accuracy: 0.6331 - val_loss: 0.8584
# Epoch 97/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 202ms/step - accuracy: 0.8808 - loss: 0.3618 - val_accuracy: 0.5401 - val_loss: 1.2516
# Epoch 98/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 204ms/step - accuracy: 0.8749 - loss: 0.3561 - val_accuracy: 0.6510 - val_loss: 0.8432
# Epoch 99/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 0.8831 - loss: 0.3594 - val_accuracy: 0.5954 - val_loss: 1.1388
# Epoch 100/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 203ms/step - accuracy: 0.8524 - loss: 0.4274 - val_accuracy: 0.5784 - val_loss: 1.0620
# Epoch 101/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 0.8932 - loss: 0.3347 - val_accuracy: 0.6351 - val_loss: 0.8312
# Epoch 102/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 207ms/step - accuracy: 0.8873 - loss: 0.3428 - val_accuracy: 0.5957 - val_loss: 1.0039
# Epoch 103/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 204ms/step - accuracy: 0.8978 - loss: 0.3061 - val_accuracy: 0.6092 - val_loss: 1.0676
# Epoch 104/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - accuracy: 0.8850 - loss: 0.3300 - val_accuracy: 0.5765 - val_loss: 0.9869
# Epoch 105/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 201ms/step - accuracy: 0.9066 - loss: 0.2908 - val_accuracy: 0.6127 - val_loss: 0.8269
# Epoch 106/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 204ms/step - accuracy: 0.8389 - loss: 0.4517 - val_accuracy: 0.5531 - val_loss: 1.1095
# Epoch 107/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 208ms/step - accuracy: 0.8729 - loss: 0.3934 - val_accuracy: 0.7234 - val_loss: 0.6945
# Epoch 108/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 207ms/step - accuracy: 0.9085 - loss: 0.2948 - val_accuracy: 0.6653 - val_loss: 0.7028
# Epoch 109/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 206ms/step - accuracy: 0.9143 - loss: 0.2636 - val_accuracy: 0.6263 - val_loss: 0.8012
# Epoch 110/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - accuracy: 0.8913 - loss: 0.3283 - val_accuracy: 0.7017 - val_loss: 0.6579
# Epoch 111/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 201ms/step - accuracy: 0.8814 - loss: 0.3594 - val_accuracy: 0.6053 - val_loss: 0.8021
# Epoch 112/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 0.8863 - loss: 0.3344 - val_accuracy: 0.6918 - val_loss: 0.6550
# Epoch 113/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 201ms/step - accuracy: 0.9074 - loss: 0.2839 - val_accuracy: 0.7327 - val_loss: 0.6576
# Epoch 114/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 207ms/step - accuracy: 0.9233 - loss: 0.2466 - val_accuracy: 0.7631 - val_loss: 0.5545
# Epoch 115/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 211ms/step - accuracy: 0.8971 - loss: 0.3085 - val_accuracy: 0.5751 - val_loss: 0.9745
# Epoch 116/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 0.9210 - loss: 0.2432 - val_accuracy: 0.6180 - val_loss: 0.7579
# Epoch 117/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 199ms/step - accuracy: 0.8991 - loss: 0.3003 - val_accuracy: 0.7694 - val_loss: 0.7437
# Epoch 118/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 204ms/step - accuracy: 0.8928 - loss: 0.3041 - val_accuracy: 0.6418 - val_loss: 0.9112
# Epoch 119/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 203ms/step - accuracy: 0.9007 - loss: 0.2972 - val_accuracy: 0.7891 - val_loss: 0.6749
# Epoch 120/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 0.9334 - loss: 0.2122 - val_accuracy: 0.6633 - val_loss: 0.8544
# Epoch 121/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 0.9296 - loss: 0.2210 - val_accuracy: 0.7239 - val_loss: 0.6487
# Epoch 122/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 207ms/step - accuracy: 0.9222 - loss: 0.2293 - val_accuracy: 0.6553 - val_loss: 0.8651
# Epoch 123/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 208ms/step - accuracy: 0.9119 - loss: 0.2579 - val_accuracy: 0.6233 - val_loss: 0.8302
# Epoch 124/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 200ms/step - accuracy: 0.8618 - loss: 0.4410 - val_accuracy: 0.6919 - val_loss: 0.7800
# Epoch 125/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 0.8737 - loss: 0.3881 - val_accuracy: 0.5709 - val_loss: 1.0964
# Epoch 126/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 206ms/step - accuracy: 0.8989 - loss: 0.3133 - val_accuracy: 0.6031 - val_loss: 0.9991
# Epoch 127/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - accuracy: 0.9039 - loss: 0.2915 - val_accuracy: 0.6070 - val_loss: 0.9150
# Epoch 128/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 200ms/step - accuracy: 0.9097 - loss: 0.2704 - val_accuracy: 0.6111 - val_loss: 1.3706
# Epoch 129/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 201ms/step - accuracy: 0.9129 - loss: 0.2801 - val_accuracy: 0.6202 - val_loss: 0.9471
# Epoch 130/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 204ms/step - accuracy: 0.9068 - loss: 0.2674 - val_accuracy: 0.6619 - val_loss: 0.9668
# Epoch 131/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 0.9256 - loss: 0.2216 - val_accuracy: 0.7190 - val_loss: 0.7313
# Epoch 132/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 209ms/step - accuracy: 0.9146 - loss: 0.2408 - val_accuracy: 0.7244 - val_loss: 0.7614
# Epoch 133/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 205ms/step - accuracy: 0.9284 - loss: 0.2076 - val_accuracy: 0.6908 - val_loss: 0.7307
# Epoch 134/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 206ms/step - accuracy: 0.9271 - loss: 0.2276 - val_accuracy: 0.8420 - val_loss: 0.4917
# Epoch 135/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 207ms/step - accuracy: 0.9288 - loss: 0.2213 - val_accuracy: 0.7719 - val_loss: 0.5916
# Epoch 136/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - accuracy: 0.9457 - loss: 0.1744 - val_accuracy: 0.6455 - val_loss: 0.8396
# Epoch 137/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 206ms/step - accuracy: 0.9350 - loss: 0.1980 - val_accuracy: 0.8449 - val_loss: 0.5021
# Epoch 138/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - accuracy: 0.9388 - loss: 0.1936 - val_accuracy: 0.7927 - val_loss: 0.5782
# Epoch 139/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 210ms/step - accuracy: 0.9420 - loss: 0.1758 - val_accuracy: 0.7364 - val_loss: 0.8347
# Epoch 140/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 203ms/step - accuracy: 0.9431 - loss: 0.1742 - val_accuracy: 0.7030 - val_loss: 0.7760
# Epoch 141/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 203ms/step - accuracy: 0.9523 - loss: 0.1533 - val_accuracy: 0.7565 - val_loss: 0.7266
# Epoch 142/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 207ms/step - accuracy: 0.9560 - loss: 0.1363 - val_accuracy: 0.7692 - val_loss: 0.6071
# Epoch 143/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 208ms/step - accuracy: 0.9427 - loss: 0.1709 - val_accuracy: 0.7777 - val_loss: 0.5575
# Epoch 144/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 205ms/step - accuracy: 0.9564 - loss: 0.1356 - val_accuracy: 0.7568 - val_loss: 0.6119
# Epoch 145/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 202ms/step - accuracy: 0.9518 - loss: 0.1530 - val_accuracy: 0.7396 - val_loss: 0.7852
# Epoch 146/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - accuracy: 0.9527 - loss: 0.1471 - val_accuracy: 0.6438 - val_loss: 0.9791
# Epoch 147/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 204ms/step - accuracy: 0.9608 - loss: 0.1221 - val_accuracy: 0.7407 - val_loss: 0.8161
# Epoch 148/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 199ms/step - accuracy: 0.9509 - loss: 0.1499 - val_accuracy: 0.7710 - val_loss: 0.6717
# Epoch 149/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 200ms/step - accuracy: 0.9600 - loss: 0.1267 - val_accuracy: 0.8064 - val_loss: 0.5055
# Epoch 150/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 0.9577 - loss: 0.1307 - val_accuracy: 0.7448 - val_loss: 0.6605
# Epoch 151/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 207ms/step - accuracy: 0.9541 - loss: 0.1399 - val_accuracy: 0.7695 - val_loss: 0.7505
# Epoch 152/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 207ms/step - accuracy: 0.9573 - loss: 0.1321 - val_accuracy: 0.7638 - val_loss: 0.6588
# Epoch 153/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 206ms/step - accuracy: 0.9569 - loss: 0.1347 - val_accuracy: 0.7567 - val_loss: 0.7478
# Epoch 154/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 210ms/step - accuracy: 0.9650 - loss: 0.1083 - val_accuracy: 0.7348 - val_loss: 0.9249
# Epoch 155/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 208ms/step - accuracy: 0.9663 - loss: 0.1028 - val_accuracy: 0.7449 - val_loss: 0.7733
# Epoch 156/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 214ms/step - accuracy: 0.9606 - loss: 0.1195 - val_accuracy: 0.7794 - val_loss: 0.7500
# Epoch 157/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 207ms/step - accuracy: 0.9575 - loss: 0.1345 - val_accuracy: 0.7379 - val_loss: 1.0270
# Epoch 158/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - accuracy: 0.9608 - loss: 0.1193 - val_accuracy: 0.7787 - val_loss: 0.7333
# Epoch 159/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - accuracy: 0.9568 - loss: 0.1284 - val_accuracy: 0.6636 - val_loss: 1.0739
# Epoch 160/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 201ms/step - accuracy: 0.9568 - loss: 0.1320 - val_accuracy: 0.7384 - val_loss: 0.8499
# Epoch 161/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 206ms/step - accuracy: 0.9605 - loss: 0.1206 - val_accuracy: 0.8185 - val_loss: 0.6059
# Epoch 162/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 207ms/step - accuracy: 0.9614 - loss: 0.1179 - val_accuracy: 0.7822 - val_loss: 0.7281
# Epoch 163/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 207ms/step - accuracy: 0.9636 - loss: 0.1120 - val_accuracy: 0.7478 - val_loss: 0.7297
# Epoch 164/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 205ms/step - accuracy: 0.9693 - loss: 0.0946 - val_accuracy: 0.7551 - val_loss: 0.7739
# Epoch 165/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - accuracy: 0.9669 - loss: 0.1026 - val_accuracy: 0.7437 - val_loss: 0.8942
# Epoch 166/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 209ms/step - accuracy: 0.9696 - loss: 0.0930 - val_accuracy: 0.7302 - val_loss: 0.9303
# Epoch 167/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 203ms/step - accuracy: 0.9683 - loss: 0.0959 - val_accuracy: 0.7405 - val_loss: 0.9355
# Epoch 168/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 207ms/step - accuracy: 0.9707 - loss: 0.0877 - val_accuracy: 0.7465 - val_loss: 0.8667
# Epoch 169/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 205ms/step - accuracy: 0.9714 - loss: 0.0872 - val_accuracy: 0.7570 - val_loss: 0.9718
# Epoch 170/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - accuracy: 0.9693 - loss: 0.0933 - val_accuracy: 0.7460 - val_loss: 0.9366
# Epoch 171/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 203ms/step - accuracy: 0.9705 - loss: 0.0895 - val_accuracy: 0.7294 - val_loss: 1.0645
# Epoch 172/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - accuracy: 0.9705 - loss: 0.0891 - val_accuracy: 0.7497 - val_loss: 0.9806
# Epoch 173/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - accuracy: 0.9664 - loss: 0.1019 - val_accuracy: 0.7424 - val_loss: 1.0208
# Epoch 174/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - accuracy: 0.9730 - loss: 0.0821 - val_accuracy: 0.6845 - val_loss: 1.2759
# Epoch 175/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 210ms/step - accuracy: 0.9683 - loss: 0.0959 - val_accuracy: 0.7443 - val_loss: 1.0563
# Epoch 176/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 204ms/step - accuracy: 0.9724 - loss: 0.0831 - val_accuracy: 0.7187 - val_loss: 1.0947
# Epoch 177/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 205ms/step - accuracy: 0.9720 - loss: 0.0839 - val_accuracy: 0.7373 - val_loss: 1.0952
# Epoch 178/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 205ms/step - accuracy: 0.8720 - loss: 0.6811 - val_accuracy: 0.2331 - val_loss: 12.5369
# Epoch 179/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 201ms/step - accuracy: 0.5220 - loss: 3.6006 - val_accuracy: 0.4093 - val_loss: 1.7867
# Epoch 180/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 200ms/step - accuracy: 0.7716 - loss: 0.7894 - val_accuracy: 0.4219 - val_loss: 2.0901
# Epoch 181/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - accuracy: 0.7583 - loss: 0.7718 - val_accuracy: 0.5078 - val_loss: 1.8589
# Epoch 182/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 199ms/step - accuracy: 0.8083 - loss: 0.6908 - val_accuracy: 0.4405 - val_loss: 1.2690
# Epoch 183/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 0.7934 - loss: 0.6550 - val_accuracy: 0.4862 - val_loss: 1.3840
# Epoch 184/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 203ms/step - accuracy: 0.8050 - loss: 0.6316 - val_accuracy: 0.5791 - val_loss: 0.8926
# Epoch 185/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 199ms/step - accuracy: 0.8257 - loss: 0.5384 - val_accuracy: 0.4967 - val_loss: 1.3329
# Epoch 186/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 198ms/step - accuracy: 0.8166 - loss: 0.5704 - val_accuracy: 0.4592 - val_loss: 1.5532
# Epoch 187/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 0.8391 - loss: 0.4959 - val_accuracy: 0.4337 - val_loss: 1.9276
# Epoch 188/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 198ms/step - accuracy: 0.7539 - loss: 0.7723 - val_accuracy: 0.5105 - val_loss: 1.3566
# Epoch 189/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 197ms/step - accuracy: 0.8561 - loss: 0.4438 - val_accuracy: 0.5627 - val_loss: 0.9627
# Epoch 190/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 0.8588 - loss: 0.4358 - val_accuracy: 0.7275 - val_loss: 0.7671
# Epoch 191/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 201ms/step - accuracy: 0.8508 - loss: 0.4478 - val_accuracy: 0.7859 - val_loss: 0.8007
# Epoch 192/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 199ms/step - accuracy: 0.8471 - loss: 0.4293 - val_accuracy: 0.8499 - val_loss: 0.7362
# Epoch 193/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 199ms/step - accuracy: 0.8365 - loss: 0.4789 - val_accuracy: 0.7485 - val_loss: 0.7300
# Epoch 194/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 203ms/step - accuracy: 0.8428 - loss: 0.4458 - val_accuracy: 0.8377 - val_loss: 0.6777
# Epoch 195/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 201ms/step - accuracy: 0.8359 - loss: 0.4555 - val_accuracy: 0.8273 - val_loss: 0.7027
# Epoch 196/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 199ms/step - accuracy: 0.8560 - loss: 0.4372 - val_accuracy: 0.4244 - val_loss: 2.1440
# Epoch 197/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 200ms/step - accuracy: 0.8217 - loss: 0.6029 - val_accuracy: 0.5536 - val_loss: 1.0712
# Epoch 198/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - accuracy: 0.8715 - loss: 0.3695 - val_accuracy: 0.6236 - val_loss: 0.9536
# Epoch 199/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 200ms/step - accuracy: 0.8542 - loss: 0.4138 - val_accuracy: 0.7780 - val_loss: 0.7897
# Epoch 200/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 0.8177 - loss: 0.5226 - val_accuracy: 0.5287 - val_loss: 1.2774

# %% [markdown]
# Тестироание

# %%
from petroscope.segmentation.eval import SegmDetailedTester
from tensorflow.keras.utils import to_categorical

tester = SegmDetailedTester(
    Path("output"),
    classes=classset,
    void_pad=0,
    void_border_width=4,
    vis_plots=False,
    vis_segmentation=True,
)

for img_p, mask_p in test_img_mask_p:
    img = load_image(img_p, normalize=True)
    img_resized = tf.image.resize(img, (256, 256))

    pred = model.predict(np.expand_dims(img_resized, axis=0))
    pred = np.argmax(pred[0], axis=-1)
    pred = pred.astype(np.uint8)
    print(f"Pred shape: {pred.shape}")

    mask = load_mask(mask_p, classes=classset, one_hot=False)
    mask_resized = tf.image.resize(mask[..., np.newaxis], (256, 256), method='nearest')
    mask_resized = mask_resized[..., 0].numpy().astype(np.uint8)
    print(f"Mask resized shape: {mask_resized.shape}")

    pred_one_hot = to_categorical(pred, num_classes=len(classset.classes))
    mask_one_hot = to_categorical(mask_resized, num_classes=len(classset.classes))
    print(f"Pred one-hot shape: {pred_one_hot.shape}")
    print(f"Mask one-hot shape: {mask_one_hot.shape}")

    metrics = tester.eval.evaluate(pred_one_hot, gt=mask_one_hot)
    metrics_void = tester.eval_void.evaluate(pred_one_hot, gt=mask_one_hot)

    print(f"Metrics for {img_p.name}:\n{metrics}")
    print(f"Metrics with void borders for {img_p.name}:\n{metrics_void}")
    print("-" * 50)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(1, 256, 256, 3))
#   warnings.warn(msg)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Pred shape: (256, 256)
# Mask resized shape: (256, 256)
# Pred one-hot shape: (256, 256, 7)
# Mask one-hot shape: (256, 256, 7)
# Metrics for test_01.jpg:
# 	 iou [soft]:
# 		 bg: 0.8588 [0.8588]
# 		 brt: 0.0000 [0.0000]
# 		 ccp/kub: 0.0692 [0.0692]
# 		 gl: 0.0408 [0.0408]
# 		 py/mrc: 0.9151 [0.9151]
# 		 sph: 0.7263 [0.7263]
# 		 tnt/ttr: 0.0000 [0.0000]
# 	 mean iou [soft]: 0.3729 [0.3729]
# 	 acc: 0.8969
#
# Metrics with void borders for test_01.jpg:
# 	 iou [soft]:
# 		 bg: 0.8588 [0.8588]
# 		 brt: 0.0000 [0.0000]
# 		 ccp/kub: 0.0692 [0.0692]
# 		 gl: 0.0408 [0.0408]
# 		 py/mrc: 0.9151 [0.9151]
# 		 sph: 0.7263 [0.7263]
# 		 tnt/ttr: 0.0000 [0.0000]
# 	 mean iou [soft]: 0.3729 [0.3729]
# 	 acc: 0.8969
#
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Pred shape: (256, 256)
# Mask resized shape: (256, 256)
# Pred one-hot shape: (256, 256, 7)
# Mask one-hot shape: (256, 256, 7)
# Metrics for test_02.jpg:
# 	 iou [soft]:
# 		 bg: 0.6540 [0.6540]
# 		 brt: 1.0000 [1.0000]
# 		 ccp/kub: 0.0000 [0.0000]
# 		 gl: 0.0069 [0.0069]
# 		 py/mrc: 0.0014 [0.0014]
# 		 sph: 0.0461 [0.0461]
# 		 tnt/ttr: 0.0000 [0.0000]
# 	 mean iou [soft]: 0.2441 [0.2441]
# 	 acc: 0.3457
#
# Metrics with void borders for test_02.jpg:
# 	 iou [soft]:
# 		 bg: 0.6540 [0.6540]
# 		 brt: 1.0000 [1.0000]
# 		 ccp/kub: 0.0000 [0.0000]
# 		 gl: 0.0069 [0.0069]
# 		 py/mrc: 0.0014 [0.0014]
# 		 sph: 0.0461 [0.0461]
# 		 tnt/ttr: 0.0000 [0.0000]
# 	 mean iou [soft]: 0.2441 [0.2441]
# 	 acc: 0.3457
#
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Pred shape: (256, 256)
# Mask resized shape: (256, 256)
# Pred one-hot shape: (256, 256, 7)
# Mask one-hot shape: (256, 256, 7)
# Metrics for test_03.jpg:
# 	 iou [soft]:
# 		 bg: 0.9029 [0.9029]
# 		 brt: 1.0000 [1.0000]
# 		 ccp/kub: 0.0000 [0.0000]
# 		 gl: 0.1002 [0.1002]
# 		 py/mrc: 0.3708 [0.3708]
# 		 sph: 0.6276 [0.6276]
# 		 tnt/ttr: 0.2755 [0.2755]
# 	 mean iou [soft]: 0.4682 [0.4682]
# 	 acc: 0.7398
#
# Metrics with void borders for test_03.jpg:
# 	 iou [soft]:
# 		 bg: 0.9029 [0.9029]
# 		 brt: 1.0000 [1.0000]
# 		 ccp/kub: 0.0000 [0.0000]
# 		 gl: 0.1002 [0.1002]
# 		 py/mrc: 0.3708 [0.3708]
# 		 sph: 0.6276 [0.6276]
# 		 tnt/ttr: 0.2755 [0.2755]
# 	 mean iou [soft]: 0.4682 [0.4682]
# 	 acc: 0.7398
#
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Pred shape: (256, 256)
# Mask resized shape: (256, 256)
# Pred one-hot shape: (256, 256, 7)
# Mask one-hot shape: (256, 256, 7)
# Metrics for test_04.jpg:
# 	 iou [soft]:
# 		 bg: 0.8952 [0.8952]
# 		 brt: 1.0000 [1.0000]
# 		 ccp/kub: 0.0000 [0.0000]
# 		 gl: 0.1820 [0.1820]
# 		 py/mrc: 0.7137 [0.7137]
# 		 sph: 0.5447 [0.5447]
# 		 tnt/ttr: 0.0000 [0.0000]
# 	 mean iou [soft]: 0.4765 [0.4765]
# 	 acc: 0.8726
#
# Metrics with void borders for test_04.jpg:
# 	 iou [soft]:
# 		 bg: 0.8952 [0.8952]
# 		 brt: 1.0000 [1.0000]
# 		 ccp/kub: 0.0000 [0.0000]
# 		 gl: 0.1820 [0.1820]
# 		 py/mrc: 0.7137 [0.7137]
# 		 sph: 0.5447 [0.5447]
# 		 tnt/ttr: 0.0000 [0.0000]
# 	 mean iou [soft]: 0.4765 [0.4765]
# 	 acc: 0.8726
#
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Pred shape: (256, 256)
# Mask resized shape: (256, 256)
# Pred one-hot shape: (256, 256, 7)
# Mask one-hot shape: (256, 256, 7)
# Metrics for test_05.jpg:
# 	 iou [soft]:
# 		 bg: 0.6161 [0.6161]
# 		 brt: 0.0001 [0.0001]
# 		 ccp/kub: 0.0083 [0.0083]
# 		 gl: 0.0040 [0.0040]
# 		 py/mrc: 0.8192 [0.8192]
# 		 sph: 0.7081 [0.7081]
# 		 tnt/ttr: 0.0000 [0.0000]
# 	 mean iou [soft]: 0.3080 [0.3080]
# 	 acc: 0.8376
#
# Metrics with void borders for test_05.jpg:
# 	 iou [soft]:
# 		 bg: 0.6161 [0.6161]
# 		 brt: 0.0001 [0.0001]
# 		 ccp/kub: 0.0083 [0.0083]
# 		 gl: 0.0040 [0.0040]
# 		 py/mrc: 0.8192 [0.8192]
# 		 sph: 0.7081 [0.7081]
# 		 tnt/ttr: 0.0000 [0.0000]
# 	 mean iou [soft]: 0.3080 [0.3080]
# 	 acc: 0.8376
#
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Pred shape: (256, 256)
# Mask resized shape: (256, 256)
# Pred one-hot shape: (256, 256, 7)
# Mask one-hot shape: (256, 256, 7)
# Metrics for test_06.jpg:
# 	 iou [soft]:
# 		 bg: 0.7937 [0.7937]
# 		 brt: 0.0002 [0.0002]
# 		 ccp/kub: 0.0130 [0.0130]
# 		 gl: 0.0161 [0.0161]
# 		 py/mrc: 0.5565 [0.5565]
# 		 sph: 0.4625 [0.4625]
# 		 tnt/ttr: 0.0000 [0.0000]
# 	 mean iou [soft]: 0.2631 [0.2631]
# 	 acc: 0.6274
#
# Metrics with void borders for test_06.jpg:
# 	 iou [soft]:
# 		 bg: 0.7937 [0.7937]
# 		 brt: 0.0002 [0.0002]
# 		 ccp/kub: 0.0130 [0.0130]
# 		 gl: 0.0161 [0.0161]
# 		 py/mrc: 0.5565 [0.5565]
# 		 sph: 0.4625 [0.4625]
# 		 tnt/ttr: 0.0000 [0.0000]
# 	 mean iou [soft]: 0.2631 [0.2631]
# 	 acc: 0.6274
#
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Pred shape: (256, 256)
# Mask resized shape: (256, 256)
# Pred one-hot shape: (256, 256, 7)
# Mask one-hot shape: (256, 256, 7)
# Metrics for test_07.jpg:
# 	 iou [soft]:
# 		 bg: 0.7836 [0.7836]
# 		 brt: 0.0000 [0.0000]
# 		 ccp/kub: 0.0069 [0.0069]
# 		 gl: 0.0764 [0.0764]
# 		 py/mrc: 0.8180 [0.8180]
# 		 sph: 0.3617 [0.3617]
# 		 tnt/ttr: 0.0000 [0.0000]
# 	 mean iou [soft]: 0.2924 [0.2924]
# 	 acc: 0.8037
#
# Metrics with void borders for test_07.jpg:
# 	 iou [soft]:
# 		 bg: 0.7836 [0.7836]
# 		 brt: 0.0000 [0.0000]
# 		 ccp/kub: 0.0069 [0.0069]
# 		 gl: 0.0764 [0.0764]
# 		 py/mrc: 0.8180 [0.8180]
# 		 sph: 0.3617 [0.3617]
# 		 tnt/ttr: 0.0000 [0.0000]
# 	 mean iou [soft]: 0.2924 [0.2924]
# 	 acc: 0.8037
#
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Pred shape: (256, 256)
# Mask resized shape: (256, 256)
# Pred one-hot shape: (256, 256, 7)
# Mask one-hot shape: (256, 256, 7)
# Metrics for test_08.jpg:
# 	 iou [soft]:
# 		 bg: 0.1901 [0.1901]
# 		 brt: 0.0001 [0.0001]
# 		 ccp/kub: 0.0012 [0.0012]
# 		 gl: 0.0000 [0.0000]
# 		 py/mrc: 0.3356 [0.3356]
# 		 sph: 0.0477 [0.0477]
# 		 tnt/ttr: 1.0000 [1.0000]
# 	 mean iou [soft]: 0.2250 [0.2250]
# 	 acc: 0.2683
#
# Metrics with void borders for test_08.jpg:
# 	 iou [soft]:
# 		 bg: 0.1901 [0.1901]
# 		 brt: 0.0001 [0.0001]
# 		 ccp/kub: 0.0012 [0.0012]
# 		 gl: 0.0000 [0.0000]
# 		 py/mrc: 0.3356 [0.3356]
# 		 sph: 0.0477 [0.0477]
# 		 tnt/ttr: 1.0000 [1.0000]
# 	 mean iou [soft]: 0.2250 [0.2250]
# 	 acc: 0.2683
#
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Pred shape: (256, 256)
# Mask resized shape: (256, 256)
# Pred one-hot shape: (256, 256, 7)
# Mask one-hot shape: (256, 256, 7)
# Metrics for test_09.jpg:
# 	 iou [soft]:
# 		 bg: 0.8837 [0.8837]
# 		 brt: 0.0000 [0.0000]
# 		 ccp/kub: 0.2218 [0.2218]
# 		 gl: 0.0017 [0.0017]
# 		 py/mrc: 0.8821 [0.8821]
# 		 sph: 0.6533 [0.6533]
# 		 tnt/ttr: 0.0070 [0.0070]
# 	 mean iou [soft]: 0.3785 [0.3785]
# 	 acc: 0.8912
#
# Metrics with void borders for test_09.jpg:
# 	 iou [soft]:
# 		 bg: 0.8837 [0.8837]
# 		 brt: 0.0000 [0.0000]
# 		 ccp/kub: 0.2218 [0.2218]
# 		 gl: 0.0017 [0.0017]
# 		 py/mrc: 0.8821 [0.8821]
# 		 sph: 0.6533 [0.6533]
# 		 tnt/ttr: 0.0070 [0.0070]
# 	 mean iou [soft]: 0.3785 [0.3785]
# 	 acc: 0.8912
#
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Pred shape: (256, 256)
# Mask resized shape: (256, 256)
# Pred one-hot shape: (256, 256, 7)
# Mask one-hot shape: (256, 256, 7)
# Metrics for test_10.jpg:
# 	 iou [soft]:
# 		 bg: 0.7534 [0.7534]
# 		 brt: 0.0000 [0.0000]
# 		 ccp/kub: 0.0362 [0.0362]
# 		 gl: 0.0503 [0.0503]
# 		 py/mrc: 0.9079 [0.9079]
# 		 sph: 0.5930 [0.5930]
# 		 tnt/ttr: 0.0000 [0.0000]
# 	 mean iou [soft]: 0.3344 [0.3344]
# 	 acc: 0.8331
#
# Metrics with void borders for test_10.jpg:
# 	 iou [soft]:
# 		 bg: 0.7534 [0.7534]
# 		 brt: 0.0000 [0.0000]
# 		 ccp/kub: 0.0362 [0.0362]
# 		 gl: 0.0503 [0.0503]
# 		 py/mrc: 0.9079 [0.9079]
# 		 sph: 0.5930 [0.5930]
# 		 tnt/ttr: 0.0000 [0.0000]
# 	 mean iou [soft]: 0.3344 [0.3344]
# 	 acc: 0.8331
#
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Pred shape: (256, 256)
# Mask resized shape: (256, 256)
# Pred one-hot shape: (256, 256, 7)
# Mask one-hot shape: (256, 256, 7)
# Metrics for test_11.jpg:
# 	 iou [soft]:
# 		 bg: 0.8362 [0.8362]
# 		 brt: 0.0000 [0.0000]
# 		 ccp/kub: 0.0286 [0.0286]
# 		 gl: 0.1062 [0.1062]
# 		 py/mrc: 0.9128 [0.9128]
# 		 sph: 0.6304 [0.6304]
# 		 tnt/ttr: 0.0000 [0.0000]
# 	 mean iou [soft]: 0.3592 [0.3592]
# 	 acc: 0.8640
#
# Metrics with void borders for test_11.jpg:
# 	 iou [soft]:
# 		 bg: 0.8362 [0.8362]
# 		 brt: 0.0000 [0.0000]
# 		 ccp/kub: 0.0286 [0.0286]
# 		 gl: 0.1062 [0.1062]
# 		 py/mrc: 0.9128 [0.9128]
# 		 sph: 0.6304 [0.6304]
# 		 tnt/ttr: 0.0000 [0.0000]
# 	 mean iou [soft]: 0.3592 [0.3592]
# 	 acc: 0.8640
#
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Pred shape: (256, 256)
# Mask resized shape: (256, 256)
# Pred one-hot shape: (256, 256, 7)
# Mask one-hot shape: (256, 256, 7)
# Metrics for test_12.jpg:
# 	 iou [soft]:
# 		 bg: 0.5795 [0.5795]
# 		 brt: 1.0000 [1.0000]
# 		 ccp/kub: 0.0000 [0.0000]
# 		 gl: 0.0000 [0.0000]
# 		 py/mrc: 0.7747 [0.7747]
# 		 sph: 0.2996 [0.2996]
# 		 tnt/ttr: 0.0101 [0.0101]
# 	 mean iou [soft]: 0.3806 [0.3806]
# 	 acc: 0.5510
#
# Metrics with void borders for test_12.jpg:
# 	 iou [soft]:
# 		 bg: 0.5795 [0.5795]
# 		 brt: 1.0000 [1.0000]
# 		 ccp/kub: 0.0000 [0.0000]
# 		 gl: 0.0000 [0.0000]
# 		 py/mrc: 0.7747 [0.7747]
# 		 sph: 0.2996 [0.2996]
# 		 tnt/ttr: 0.0101 [0.0101]
# 	 mean iou [soft]: 0.3806 [0.3806]
# 	 acc: 0.5510
#
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Pred shape: (256, 256)
# Mask resized shape: (256, 256)
# Pred one-hot shape: (256, 256, 7)
# Mask one-hot shape: (256, 256, 7)
# Metrics for test_13.jpg:
# 	 iou [soft]:
# 		 bg: 0.9577 [0.9577]
# 		 brt: 1.0000 [1.0000]
# 		 ccp/kub: 0.0000 [0.0000]
# 		 gl: 0.0000 [0.0000]
# 		 py/mrc: 0.1743 [0.1743]
# 		 sph: 0.6625 [0.6625]
# 		 tnt/ttr: 0.0776 [0.0776]
# 	 mean iou [soft]: 0.4103 [0.4103]
# 	 acc: 0.8019
#
# Metrics with void borders for test_13.jpg:
# 	 iou [soft]:
# 		 bg: 0.9577 [0.9577]
# 		 brt: 1.0000 [1.0000]
# 		 ccp/kub: 0.0000 [0.0000]
# 		 gl: 0.0000 [0.0000]
# 		 py/mrc: 0.1743 [0.1743]
# 		 sph: 0.6625 [0.6625]
# 		 tnt/ttr: 0.0776 [0.0776]
# 	 mean iou [soft]: 0.4103 [0.4103]
# 	 acc: 0.8019
#
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Pred shape: (256, 256)
# Mask resized shape: (256, 256)
# Pred one-hot shape: (256, 256, 7)
# Mask one-hot shape: (256, 256, 7)
# Metrics for test_14.jpg:
# 	 iou [soft]:
# 		 bg: 0.8730 [0.8730]
# 		 brt: 0.0724 [0.0724]
# 		 ccp/kub: 0.0000 [0.0000]
# 		 gl: 0.0176 [0.0176]
# 		 py/mrc: 0.9083 [0.9083]
# 		 sph: 0.5367 [0.5367]
# 		 tnt/ttr: 0.0000 [0.0000]
# 	 mean iou [soft]: 0.3440 [0.3440]
# 	 acc: 0.8722
#
# Metrics with void borders for test_14.jpg:
# 	 iou [soft]:
# 		 bg: 0.8730 [0.8730]
# 		 brt: 0.0724 [0.0724]
# 		 ccp/kub: 0.0000 [0.0000]
# 		 gl: 0.0176 [0.0176]
# 		 py/mrc: 0.9083 [0.9083]
# 		 sph: 0.5367 [0.5367]
# 		 tnt/ttr: 0.0000 [0.0000]
# 	 mean iou [soft]: 0.3440 [0.3440]
# 	 acc: 0.8722
#
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Pred shape: (256, 256)
# Mask resized shape: (256, 256)
# Pred one-hot shape: (256, 256, 7)
# Mask one-hot shape: (256, 256, 7)
# Metrics for test_15.jpg:
# 	 iou [soft]:
# 		 bg: 0.9273 [0.9273]
# 		 brt: 0.6062 [0.6062]
# 		 ccp/kub: 0.0000 [0.0000]
# 		 gl: 0.0000 [0.0000]
# 		 py/mrc: 0.8660 [0.8660]
# 		 sph: 0.3229 [0.3229]
# 		 tnt/ttr: 0.0000 [0.0000]
# 	 mean iou [soft]: 0.3889 [0.3889]
# 	 acc: 0.8951
#
# Metrics with void borders for test_15.jpg:
# 	 iou [soft]:
# 		 bg: 0.9273 [0.9273]
# 		 brt: 0.6062 [0.6062]
# 		 ccp/kub: 0.0000 [0.0000]
# 		 gl: 0.0000 [0.0000]
# 		 py/mrc: 0.8660 [0.8660]
# 		 sph: 0.3229 [0.3229]
# 		 tnt/ttr: 0.0000 [0.0000]
# 	 mean iou [soft]: 0.3889 [0.3889]
# 	 acc: 0.8951
#
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Pred shape: (256, 256)
# Mask resized shape: (256, 256)
# Pred one-hot shape: (256, 256, 7)
# Mask one-hot shape: (256, 256, 7)
# Metrics for test_16.jpg:
# 	 iou [soft]:
# 		 bg: 0.8700 [0.8700]
# 		 brt: 0.0066 [0.0066]
# 		 ccp/kub: 0.0005 [0.0005]
# 		 gl: 1.0000 [1.0000]
# 		 py/mrc: 0.0000 [0.0000]
# 		 sph: 0.4896 [0.4896]
# 		 tnt/ttr: 0.0001 [0.0001]
# 	 mean iou [soft]: 0.3381 [0.3381]
# 	 acc: 0.5125
#
# Metrics with void borders for test_16.jpg:
# 	 iou [soft]:
# 		 bg: 0.8700 [0.8700]
# 		 brt: 0.0066 [0.0066]
# 		 ccp/kub: 0.0005 [0.0005]
# 		 gl: 1.0000 [1.0000]
# 		 py/mrc: 0.0000 [0.0000]
# 		 sph: 0.4896 [0.4896]
# 		 tnt/ttr: 0.0001 [0.0001]
# 	 mean iou [soft]: 0.3381 [0.3381]
# 	 acc: 0.5125
#
# --------------------------------------------------
